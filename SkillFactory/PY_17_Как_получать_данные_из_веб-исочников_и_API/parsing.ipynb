# %% [markdown]
# ### <center>Библиотека requests

# %% [markdown]
# Познакомимся с библиотекой requests, решив простую задачу — получить значения курсов валют. Курс валют — полезная и регулярно обновляемая информация, но каждый раз в ручном режиме получать информацию о курсе интересующей валюты трудоёмко.

# %% [markdown]
# Разработаем код, так называемый скрипт (англ. script, рус. сценарий), — небольшую программу, которая содержит последовательность действий для автоматического выполнения задачи.

# %% [markdown]
# С помощью скрипта мы будем в удобном виде выгружать информацию по курсам валют с заранее выбранного сайта.

# %% [markdown]
# Один из сайтов в интернете, на котором информация о курсах валют дублирует информацию с сайта Центрального Банка России https://www.cbr.ru/, — ресурс Курсы валют ЦБ РФ в XML и JSON https://www.cbr-xml-daily.ru/. На данном ресурсе информация о курсах валют представлена в разных форматах, в том числе и в структурированном JSON-формате, методы работы с которым мы изучили в одном из предыдущих модулей.

# %% [markdown]
# Перед началом работы библиотеку requests потребуется установить. Например, в Jupyter Notebook это делается с помощью такой команды:

# %%
# Устанавливаем библиотеку requests
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (from requests) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (from requests) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.4)

# %% [markdown]
# Как только библиотека установлена, импортируем её и отправим наш первый запрос к ресурсу Курсы валют ЦБ РФ в XML и JSON https://www.cbr-xml-daily.ru/. Используем метод get() из библиотеки requests, передав ему соответствующий URL —  https://www.cbr-xml-daily.ru/daily_json.js:

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

# %% [markdown]
# Проверим ответ сервера — содержимое переменной response:

# %%
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %% [markdown]
# Мы получили объект ответа Response, который содержит всю нужную нам информацию. По умолчанию в квадратных скобках на экран выводится код статуса ответа. В данном случае он равен 200 — то есть запрос был корректным и сервер отдал нам нужную информацию. Значение кода статуса 404 означало бы, что страница по указанному адресу не найдена, а значение 403 — что синтаксис GET-запроса неверный.

# %% [markdown]
# Код ответа в виде числовой переменной можно получить с помощью метода status_code:

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %%
url = 'https://www.cbr-xml-daily.ru/daily.xml' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %% [markdown]
# ### <center>РАБОТАЕМ С ОТВЕТОМ

# %% [markdown]
# Мы сделали запрос и получили корректный ответ (код статуса — 200). Дальнейшую работу производим с результатом запроса к ресурсу Курсы валют ЦБ РФ в XML и JSON.
#
# ?  Как получить доступ ко всей информации, которую содержит ответ?

# %% [markdown]
# Текст ответа хранится в атрибуте text. Выведем значение атрибута на экран и посмотрим на его содержимое:

# %%
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# {
#     "Date": "2022-12-31T11:30:00+03:00",
#     "PreviousDate": "2022-12-30T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2022\/12\/30\/daily_json.js",
#     "Timestamp": "2023-01-03T11:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 47.6537,
#             "Previous": 48.5922
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 41.375,
#             "Previous": 42.3399
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 84.7919,
#             "Previous": 86.6397
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 17.8717,
#             "Previous": 18.2959
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 25.7044,
#             "Previous": 26.3038
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 38.2977,
#             "Previous": 39.0908
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 13.4813,
#             "Previous": 13.6495
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 18.7227,
#             "Previous": 19.0538
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 90.3965,
#             "Previous": 92.5165
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 10.0722,
#             "Previous": 10.2984
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 70.3375,
#             "Previous": 71.9778
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 75.6553,
#             "Previous": 76.0765
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 84.8785,
#             "Previous": 87.0686
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 15.2583,
#             "Previous": 15.6056
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 51.8828,
#             "Previous": 53.0614
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 82.0933,
#             "Previous": 84.0077
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 10,
#             "Name": "Китайских юаней",
#             "Value": 98.9492,
#             "Previous": 10.1306
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 36.7146,
#             "Previous": 37.5591
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 71.511,
#             "Previous": 72.6388
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 16.0496,
#             "Previous": 16.3122
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 15.1766,
#             "Previous": 15.4788
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 93.608,
#             "Previous": 95.7909
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 52.3111,
#             "Previous": 53.3841
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 68.9421,
#             "Previous": 70.5582
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 37.5865,
#             "Previous": 38.4634
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 20.0964,
#             "Previous": 20.5651
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 62.6589,
#             "Previous": 64.2913
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 19.1387,
#             "Previous": 19.4894
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 30.9611,
#             "Previous": 31.5747
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 67.3918,
#             "Previous": 68.7152
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 76.1805,
#             "Previous": 77.9487
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 41.4162,
#             "Previous": 42.3008
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 55.6248,
#             "Previous": 56.9219
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 53.0609,
#             "Previous": 53.7028
#         }
#     }
# }

# %% [markdown]
# *Как правило, при работе над реальным проектом на этапе получения данных мы уже понимаем, с какими форматами данных нам придётся работать. На предлагаемом для работы ресурсе информация есть как в JSON-формате, так и в XML. По нашему запросу ресурс возвращает информацию в JSON-формате, однако в настоящий момент результат хранится как единая строка. Проверить тип данных полученного ответа можно, воспользовавшись функцией type().*

# %% [markdown]
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь. В объект ответа Response  из библиотеки requests уже встроен метод json() .
#
# Импортируем функцию pprint(), применим к полученному ответу метод json() и выведем полученный результат на экран:

# %%
from pprint import pprint # Импортируем функцию pprint()
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2022-12-31T11:30:00+03:00',
#  'PreviousDate': '2022-12-30T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/12/30/daily_json.js',
#  'Timestamp': '2023-01-03T11:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 18.2959,
#                     'Value': 17.8717},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 48.5922,
#                     'Value': 47.6537},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 42.3399,
#                     'Value': 41.375},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 39.0908,
#                     'Value': 38.2977},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 13.6495,
#                     'Value': 13.4813},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 26.3038,
#                     'Value': 25.7044},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 53.0614,
#                     'Value': 51.8828},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 77.9487,
#                     'Value': 76.1805},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайских юаней',
#                     'Nominal': 10,
#                     'NumCode': '156',
#                     'Previous': 10.1306,
#                     'Value': 98.9492},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 31.5747,
#                     'Value': 30.9611},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 10.2984,
#                     'Value': 10.0722},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 76.0765,
#                     'Value': 75.6553},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 86.6397,
#                     'Value': 84.7919},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 92.5165,
#                     'Value': 90.3965},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 19.0538,
#                     'Value': 18.7227},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 87.0686,
#                     'Value': 84.8785},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 53.7028,
#                     'Value': 53.0609},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 84.0077,
#                     'Value': 82.0933},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 56.9219,
#                     'Value': 55.6248},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 15.6056,
#                     'Value': 15.2583},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 37.5591,
#                     'Value': 36.7146},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 72.6388,
#                     'Value': 71.511},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 16.3122,
#                     'Value': 16.0496},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 15.4788,
#                     'Value': 15.1766},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 68.7152,
#                     'Value': 67.3918},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 53.3841,
#                     'Value': 52.3111},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 70.5582,
#                     'Value': 68.9421},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 20.5651,
#                     'Value': 20.0964},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 38.4634,
#                     'Value': 37.5865},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 19.4894,
#                     'Value': 19.1387},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 71.9778,
#                     'Value': 70.3375},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 64.2913,
#                     'Value': 62.6589},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 95.7909,
#                     'Value': 93.608},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 42.3008,
#                     'Value': 41.4162}}}

# %% [markdown]
# Теперь данные находятся в словаре и можно легко получать необходимые значения.
#
# Например, по ключу Valute мы можем обратиться к вложенному словарю, который содержит информацию о мировых валютах. Выведем на экран, например, информацию о евро (EUR):

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 76.0765,
#  'Value': 75.6553}

# %%
pprint(currencies['Valute']['USD']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'USD',
#  'ID': 'R01235',
#  'Name': 'Доллар США',
#  'Nominal': 1,
#  'NumCode': '840',
#  'Previous': 71.9778,
#  'Value': 70.3375}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ### <center>Парсинг сайтов

# %% [markdown]
# *✍ Ресурс, с которым мы работали в предыдущем юните, возвращал ответ о текущем курсе валют в удобном, структурированном формате, из которого было легко извлечь необходимую информацию. Довольно часто для получения информации приходится обращаться напрямую к HTML-страницам.*

# %% [markdown]
# Для примера рассмотрим страницу https://nplus1.ru/news/2021/10/11/econobel2021, содержащую статью с информацией о присуждении Нобелевской премии по экономике в 2021 году, и попробуем извлечь из неё заголовок статьи, опубликованной на странице, дату публикации, а также текст статьи.
#
# Получить содержимое страницы в большинстве случаев несложно, гораздо труднее извлечь из HTML-кода нужную информацию.
#
# ?  Что собой представляет HTML?

# %% [markdown]
# #### <center>ОСНОВЫ HTML

# %% [markdown]
# ***HTML** (англ. HyperText Markup Language, рус. язык гипертекстовой разметки) — стандартизированный язык разметки документов в интернете. Большинство веб-страниц содержат описание разметки на языке HTML. Язык HTML интерпретируется браузерами. Полученный в результате интерпретации текст отображается на экране монитора компьютера или мобильного устройства.*

# %% [markdown]
# HTML позволяет создавать макет страницы, разбивая её на блоки: мы можем поместить содержимое посередине страницы, сбоку и т. п.
#
# Кроме того, HTML используется для описания форматирования. Например, с его помощью мы можем указать, какая часть текста должна отображаться крупным шрифтом как заголовок, какая — курсивом, а какая — как обычный текст.
#
# HTML является близким родственником уже знакомого вам формата XML. Разметка на языке HTML делается с помощью так называемых **тегов**, которые помещаются в угловые скобки, и применяется к элементам, заключённым внутри них. Посмотрите на примеры:
#
# ```python
#
# <h2> Это заголовок второго уровня </h2>
# <div> А это обычный текст </div>
# ```

# %% [markdown]
# У корректной HTML-страницы есть заголовок и тело страницы. В заголовке (в тегах **<*head*>** … **<*/head*>**)  размещается техническая информация, подключаются скрипты и стили. В теле **<*body*>** … **<*/body*>** находятся текст и данные, которые непосредственно отображаются на странице в браузере.
#
# Разметка небольшой страницы выглядит примерно так:
#
# ```python
# <!DOCTYPE html>
# <html lang="ru">
#     <head>
#         <title>Название страницы</title>
#         <meta charset="UTF-8">
#     </head>
#     <body>
#         <h1> Это заголовок страницы </h1>
#         <p> Какой-то текст </p>
#     </body>
# </html>
# ```

# %% [markdown]
# Вы можете сохранить этот код в текстовом файле с расширением .html и открыть этот файл в браузере.

# %% [markdown]
# *Обратите внимание, что теги образуют иерархическую структуру, то есть одни теги расположены внутри других. В примере выше тег **<*p*>** … </p*> находится внутри тега **<*body*>** … **<*/body*>**.*

# %% [markdown]
# Кроме того, у тегов могут быть атрибуты, которые пишутся внутри открывающегося тега. Самые популярные атрибуты — это class и id:
#
# ```python
# <h1 id="big-title"> Заголовок страницы </h1>
# <p class="red-back"> Какой-то текст </p>
# ```

# %% [markdown]
# Изучение языка HTML находится вне рамок этого курса, но для того, чтобы собирать информацию с веб-страниц, нет необходимости хорошо знать HTML. Достаточно понимать, что:
#
# * существуют теги с разными именами;
# * у тегов бывают атрибуты, такие как class и id;
# * теги образуют иерархическую структуру, то есть одни теги вложены в другие.

# %% [markdown]
# Вы можете ознакомиться с информацией о HTML в справочнике, перейдя по ссылке http://htmlbook.ru/html.

# %% [markdown]
# #### <center>ПОЛУЧАЕМ СОДЕРЖИМОЕ ВЕБ-СТРАНИЦЫ

# %% [markdown]
# Получим HTML-код интересующей нас страницы.
#
# Для этого отправим GET-запрос с помощью библиотеки requests и метода get() и посмотрим на текст ответа на наш запрос (как мы помним, он содержится в атрибуте text):

# %%
#import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#" lang="ru">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#   <link href="/front-build/css/main.css?v=6" rel="stylesheet">
#   <link href="/front-build/css/app.css?v=6" rel="stylesheet">
#
#
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#   <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#   <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#   <link rel="manifest" href="/site.webmanifest">
#   <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#f26e40">
#   <meta name="msapplication-TileColor" content="#f26e40">
#   <meta name="theme-color" content="#ffffff">
#
#   <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021">
#
#   <meta name="yandex-verification" content="8c90b02c84ac3b72"/>
#   <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#   <script>window.yaContextCb = window.yaContextCb || []</script>
#   <script src="https://yandex.ru/ads/system/context.js" async></script>
#
#
#
#   <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#   <meta property="og:site_name" content="N + 1 — главное издание о науке, технике и технологиях"/>
#   <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta property="og:image" content="https://app-images.website.yandexcloud.net/250227/6301a13e6b36b_cover_share.jpg"/>
#   <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021"/>
#   <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta property="og:type" content="article"/>
#
#     <meta itemprop="datePublished" content="2021-10-11"/>
#   <!-- amp page -->
#   <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#
#   <meta itemprop="datePublished" content="2021-10-11"/>
#
#
#
#       <meta name="mediator_author" content="Илья Ферапонтов"/>
#     <meta name="author" content="Илья Ферапонтов"/>
#
#   <meta name="copyright" content=""/>
#
#       <script type="application/ld+json">
#     {
#       "@context": "https://schema.org",
#       "@type": "NewsArticle",
#       "mainEntityOfPage": {
#         "@type": "WebPage",
#         "@id": "https://nplus1.ru/news/2021/10/11/econobel2021"
#       },
#       "headline": "Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей",
#       "description": "",
#             "image": "https://app-images.website.yandexcloud.net/250227/6301a13e6b36b_cover_share.jpg",
#
#
#
#           "author": {
#         "@type": "Person",
#         "name": "Илья Ферапонтов",
#                 "image": "https://app-images.website.yandexcloud.net/731264/c1f15e96daa1dca3643dec0098cd5e79.jpg",
#                 "url": "https://nplus1.ru/author/ilya-ferapontov"
#         },
#         "publisher": {
#       "@type": "Organization",
#       "name": "N+1",
#       "logo": {
#         "@type": "ImageObject",
#         "url": "https://nplus1.ru/images-new/logo-alt.png"
#       }
#     },
#     "datePublished": "2021-10-11",
#       "dateModified": "2021-10-11"
#     }
#
#
#     </script>
#
#
#
#   <meta name="twitter:card" content="summary_large_image">
#   <meta name="twitter:site" content="@nplusodin"/>
#   <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей"/>
#   <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. "/>
#   <meta name="twitter:image" content="https://app-images.website.yandexcloud.net/250227/6301a13e6b36b_cover_share.jpg"/>
#
#   <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#
#
#
#
#
#
#
#
#
#
#
#
# </head>
# <body class="antialiased">
# <div id="appfront" class="font-aeonik text-main-black flex flex-col min-h-screen pt-15 bg-light-gray">
#
#   <header class="bg-light-gray fixed h-15 left-0 top-0 w-full z-50"
#         data-ref-header
#         ref="headerRef">
#
#       <div id="progressBar" class="absolute bg-main-gray/5 bottom-0 left-0 top-0" style="z-index: -1"></div>
#
#   <div class="border-b border-main-gray h-full">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto flex justify-between items-center h-full"
#          data-ref-header-container
#          ref="headerContainerRef">
#
#       <button aria-label="Go" data-ref-header-menu-btn
#               ref="headerMenuBtnRef"
#               id="topMenuBtn"
#               @click="menuOpen"
#               class="w-7.5 h-7.5">
#         <template v-if="isOpenDesktopMenu || isOpenMobileMenu">
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_cross_menu"></use>
#           </svg>
#         </template>
#         <template v-else>
#           <svg class="w-full h-full">
#             <use xlink:href="#n1_burger"></use>
#           </svg>
#         </template>
#       </button>
#
#       <div>
#                   <a href="/">
#                         <img loading="lazy" src="/images-new/logo.svg" height="23" width="57" alt="as">
#                       </a>
#               </div>
#
#       <a href="/search" class="w-7.5 h-7.5">
#         <svg class="w-full h-full">
#           <use xlink:href="#n1_pupa"></use>
#         </svg>
#       </a>
#     </div>
#   </div>
#
#   <nav v-if="isOpenDesktopMenu" id="navMenu" class="relative bg-light-gray max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavDesktop">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#       <div class="py-12 mb-12 border-b border-gray-2 text-18 grid grid-cols-flow lg:grid-cols-12 gap-x-5 md:gap-x-9">
#
#
#         <!--
#         <a @click.native="menuClose"
#            class="col-span-3 flex gap-x-2 lg:gap-x-5 items-center hover:text-main transition-colors duration-75"
#            href="/lk">
#           <svg class="h-10 lg:h-12 w-10 lg:w-12 shrink-0">
#             <use xlink:href="#n1_person"></use>
#           </svg>
#           <span>Личный кабинет</span>
#         </a>
#         -->
#
#         <a class="col-span-3 lg:col-span-2 col-start-7 lg:col-start-9 flex items-center hover:text-main transition-colors duration-75"
#            href="https://offline.nplus1.ru/">N + offline</a>
#         <a class="col-span-3 lg:col-span-2 col-start-10 lg:col-start-11 flex items-center hover:text-main transition-colors duration-75"
#            href="https://nplus.pro/">N + production</a>
#       </div>
#       <div class="grid grid-cols-12 gap-x-5 gap-y-5 md:gap-y-9 pb-6">
#         <div class="col-span-6 md:col-span-3 text-20 lg:text-26 xl:text-34 font-spectral flex flex-col gap-y-3">
#
#                                     <a target="_blank" href="https://nplus1.ru/about" class="hover:text-main transition-colors duration-75">
#                 О нас
#               </a>
#                                                 <a target="_blank" href="https://nplus1.ru/difficult" class="hover:text-main transition-colors duration-75">
#                 Сложность
#               </a>
#                                                 <a target="_blank" href="https://nplus1.ru/adv" class="hover:text-main transition-colors duration-75">
#                 Рекламодателям
#               </a>
#                                                 <a target="_blank" href="https://nplus1.ru/blog/2022/04/01/samotek" class="hover:text-main transition-colors duration-75">
#                 Авторам
#               </a>
#
#         </div>
#
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/869">Физика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/874">Зоология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/880">Астрономия</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/768">Генетика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/890">Математика</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/871">Космонавтика</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/876">Археология</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/775">Нейронауки</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/767">На мышах</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/771">Звук</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/772">Красота</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/778">Научные закрытия</a>
#                       </div>
#                   <div class="col-span-6 md:col-span-3 text-18 lg:text-24 xl:text-32 text-main flex flex-col gap-y-3">
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/917">ИИ спешит на помощь</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/918">Когда рассеется дым</a>
#                           <a class="hover:underline transition-colors duration-75"
#                  href="/search/empty/824">Книжная полка</a>
#                       </div>
#
#       </div>
#       <div class="py-12 mt-auto border-t border-gray-2 text-18 grid grid-cols-12 gap-x-5 md:gap-x-9">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </nav>
#
#   <nav v-if="isOpenMobileMenu" id="mobNavMenu" class="relative bg-white max-h-0 n1_top_nav overflow-hidden"
#        :style="stylesNavMobile">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto h-full flex flex-col overflow-y-auto">
#
#       <div class="text-30 font-spectral flex flex-col gap-y-5 mb-10 mt-10">
#         <a class="hover:text-main transition-colors duration-75" target="_blank" href="https://nplus1.ru/about">О
#           нас</a>
#         <a class="hover:text-main transition-colors duration-75" target="_blank" href="https://nplus1.ru/difficult">Сложность</a>
#         <a class="hover:text-main transition-colors duration-75" target="_blank" href="https://nplus1.ru/adv">Рекламодателям</a>
#         <a class="hover:text-main transition-colors duration-75" target="_blank"
#            href="https://nplus1.ru/news/2015/09/21/editor-thy-name">Вакансии</a>
#       </div>
#       <div class="text-28 text-main flex flex-col gap-y-2.5 mb-10">
#
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/869">Физика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/874">Зоология</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/880">Астрономия</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/768">Генетика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/890">Математика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/871">Космонавтика</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/876">Археология</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/775">Нейронауки</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/767">На мышах</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/771">Звук</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/772">Красота</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/778">Научные закрытия</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/917">ИИ спешит на помощь</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/918">Когда рассеется дым</a>
#                   <a class="hover:underline transition-colors duration-75"
#              href="/search/empty/824">Книжная полка</a>
#
#       </div>
#       <div class="max-w-full flex py-5 border-t border-gray-2">
#         <div class="flex gap-x-5 overflow-x-auto">
#
#           <a class="hover:text-main whitespace-nowrap" href="https://offline.nplus1.ru/">N + offline</a>
#           <a class="hover:text-main whitespace-nowrap" href="https://nplus.pro/">N + production</a>
#         </div>
#       </div>
#       <div class="pt-5 pb-10 border-t border-gray-2 text-18">
#         <ul class="flex gap-2.5">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-10 h-10">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#
#     </div>
#   </nav>
#
# </header>
#
#
#   <app-heading-nav></app-heading-nav>
#
#   <section class="mb-15 md:mb-20">
#     <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9 relative overflow-hidden"
#          data-heading-wrap>
#
#       <!--tags-->
#
#               <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 mt-5 -mb-2.5 lg:-mb-0 lg:mt-10 content-start mr-9">
#           <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#                           <span class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center">
#                 <span class="group-hover:text-main transition-colors duration-75">13:04</span>
#               </span>
#
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/news/2021/10/11">
#               <span class="group-hover:text-main transition-colors duration-75">11.10.21</span>
#             </a>
#             <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                href="/material/difficulty/1">
#               <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#                 <use xlink:href="#n1_star"></use>
#               </svg>
#               <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#             </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="/search/empty/898">
#                   <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#                 </a>
#
#                                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                    href="/search/empty/785">
#                   <span class="group-hover:text-main transition-colors duration-75">Нобелевская премия</span>
#                 </a>
#
#           </div>
#           <div class="hidden lg:flex items-center gap-x-2">
#
#             <a href="https://nplus1.ru/material-print/30917" target="_blank" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22"
#                    height="30" viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"/>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"/>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"/>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"/>
#               </svg>
#             </a>
#
#
#
#
#
#
#             <app-copy-material
#                     link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                     type="full-2"
#             ></app-copy-material>
#
#           </div>
#
#           <div class="w-full flex flex-col mt-5">
#
#
#
#           </div>
#
#         </div>
#
#       <!--dotes menu mobile-->
#       <template v-if="isMobile">
#         <button
#                 @click="openMobileDotsMenu"
#                 class="absolute flex right-5 top-5 z-30 text-main-black" >
#           <svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" viewBox="0 0 30 30" fill="none"
#                class="fill-current">
#             <path fill-rule="evenodd" clip-rule="evenodd"
#                   d="M17 6C17 6.55228 16.5523 7 16 7H15C14.4477 7 14 6.55228 14 6V5C14 4.44772 14.4477 4 15 4H16C16.5523 4 17 4.44772 17 5V6ZM17 23C17 23.5523 16.5523 24 16 24H15C14.4477 24 14 23.5523 14 23V22C14 21.4477 14.4477 21 15 21H16C16.5523 21 17 21.4477 17 22V23ZM14 14.5C14 15.0523 14.4477 15.5 15 15.5H16C16.5523 15.5 17 15.0523 17 14.5V13.5C17 12.9477 16.5523 12.5 16 12.5H15C14.4477 12.5 14 12.9477 14 13.5V14.5Z"/>
#           </svg>
#         </button>
#         <div ref="mobileDotsMenuRef"
#              :class="{
#            'transition-transform flex items-center gap-x-7.5 absolute top-0 right-0 w-full px-6 md:px-8 h-20 bg-white z-30 justify-end bg-light-gray':true,
#            '-translate-x-full': !isOpenMobileDotsMenu,
#            '-translate-x-0': isOpenMobileDotsMenu
#            }">
#
#
#
#
#
#           <app-copy-material
#                   link="https://nplus1.ru/news/2021/10/11/econobel2021"
#                   type="mobile"
#           ></app-copy-material>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <path d="M14.3303 26.2967L0.5 38.8697V0.5H28.8333V38.8697L15.003 26.2967L14.6667 25.9909L14.3303 26.2967Z"/>
#             </svg>
#           </button>
#
#           <button aria-label="Go" class="group">
#             <svg class="group-focus:text-main transition-colors duration-75 stroke-current"
#                  xmlns="http://www.w3.org/2000/svg" width="30" height="40" viewBox="0 0 30 40" fill="none">
#               <rect x="0.833984" y="0.5" width="28.3333" height="39"/>
#               <line x1="5.66732" y1="10.1665" x2="24.334" y2="10.1665"/>
#               <line x1="5.66732" y1="28.8335" x2="24.334" y2="28.8335"/>
#               <line x1="5.66732" y1="19.5" x2="24.334" y2="19.5"/>
#             </svg>
#           </button>
#
#         </div>
#       </template>
#
#       <!-- main image -->
#             <!--main-->
#
#       <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10">
#         <div class="flex flex-col">
#
#
#           <h1 class="text-34 md:text-42 xl:text-52 break-words mb-6">
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#           </h1>
#
#
#
#                       <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#
#                 <span class="whitespace-nowrap">
#
#                   <a class="underline" href="/author/ilya-ferapontov">Илья Ферапонтов</a>
#                 </span>
#
#
#
#
#             </div>
#
#           <div data-lmb-0 class="mb-14">
#
#
#
#                                     <BaseGalleryMain :gid="18670"></BaseGalleryMain>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a> на официальном сайте Нобелевской премии.</p></div>
#
#
#
#
#
#                                     <BaseGalleryMain :gid="1381"></BaseGalleryMain>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6">В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале <a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на бедных»</a>. В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p></div>
#
#
#
#                               <div class="n1_material text-18"><p class="mb-6"><i>Сергей Кузнецов</i></p></div>
#
#
#                       </div>
#
#
#
#
#
#
#
#           <div class="text-18">
#
#
#             <div class="text-20 font-spectral text-main-gray leading-none" v-if="!isMobile">
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#             </div>
#
#           </div>
#
#         </div>
#       </div>
#
#       <!--right sidebar-->
#
#       <div class="hidden md:block md:col-span-4 lg:col-span-3 mt-10 ">
#
#
#
#
#
#                               <a href="http://nplus.pro/?utm_source=nplus1&utm_medium=banner&utm_campaign=bodykit">
#               <img loading="lazy" src="/images-new/banner-test.png" class="w-full" alt="banner">
#             </a>
#
#             <!-- ba2 -->
#             <!--AdFox START-->
#             <!--nplus1_dir-->
#             <!--Площадка: https://nplus1.ru/ / * / *-->
#             <!--Тип баннера: CLICKIO html5-->
#             <!--Расположение: <верх страницы>-->
#             <div id="adfox_153934342663011746" class="bg-gray-100 mt-2 py-4 w-full"></div>
#
#
#
#
#
#
#         <!--
#         <a class="text-14 leading-21 group" href="#">
#           <p>
#             Human mobility at Tell Atchana (Alalakh), Hatay, Turkey during the 2nd millennium BC: Integration of
#             isotopic and genomic evidence
#           </p>
#           <div class="group-hover:text-main inline-flex items-center font-spectral text-main-gray">
#             <p class="mr-1">PLOS ONE, 30.06.2021</p>
#             <svg class="fill-current" width="11" height="11" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#                     fill="currentColor"></path>
#             </svg>
#           </div>
#         </a>
#         -->
#
#       </div>
#
#
#
#     </div>
#   </section>
#
#
#       <section class="mb-15 md:mb-20">
#
#
#   <div class="2xl:max-w-1280 px-6 md:px-8 lg:px-10 xl:px-20 2xl:px-0 mx-auto grid grid-cols-6 md:grid-cols-12 gap-x-5 md:gap-x-9">
#
#     <!--tags-->
#
#           <div class="flex-wrap col-span-6 md:col-span-12 lg:col-span-2 -mb-2.5 lg:-mb-0 content-start">
#         <div class="flex flex-wrap lg:mb-10 gap-2 text-tags xl:pr-9">
#
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/blog/2021/09/28">
#             <span class="group-hover:text-main transition-colors duration-75">28.09.21</span>
#           </a>
#
#           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#              href="/material/difficulty/1">
#             <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#               <use xlink:href="#n1_star"></use>
#             </svg>
#             <span class="group-hover:text-main transition-colors duration-75">1.1</span>
#           </a>
#
#                                     <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="/search/empty/906">
#                 <span class="group-hover:text-main transition-colors duration-75">Ex libris</span>
#               </a>
#                           <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="/search/empty/898">
#                 <span class="group-hover:text-main transition-colors duration-75">Экономика</span>
#               </a>
#
#                                     <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 group pl-2 flex inline-flex items-center"
#                  href="/search/empty/824">
#                 <span class="group-hover:text-main transition-colors duration-75">Книжная полка</span>
#               </a>
#
#         </div>
#         <div class="hidden lg:flex items-center gap-x-2">
#
#
#
#
#
#
#
#
#                       <a href="https://nplus1.ru/material-print/30758" aria-label="Go" class="group">
#               <svg class="group-hover:text-main transition-colors duration-75 stroke-current" width="22" height="30"
#                    viewBox="0 0 22 30" fill="none" xmlns="http://www.w3.org/2000/svg">
#                 <rect x="0.5" y="0.5" width="21" height="29"></rect>
#                 <line x1="4" y1="7.5" x2="18" y2="7.5"></line>
#                 <line x1="4" y1="21.5" x2="18" y2="21.5"></line>
#                 <line x1="4" y1="14.5" x2="18" y2="14.5"></line>
#               </svg>
#             </a>
#
#
#
#
#
#
#                       <app-copy-material
#                     link="https://nplus1.ru/blog/2021/09/28/unsere-welt-neu-denken"
#                     type="full-2"
#             ></app-copy-material>
#
#         </div>
#       </div>
#
#     <!--main image  -->
#
#
#
#     <!--main-->
#
#     <div class="col-span-6 md:col-span-8 lg:col-span-7 lg:col-start-3 row-span-2 lg:border-l lg:border-gray-200 xl:-ml-9 lg:pl-9 mt-10 lg:mt-0 ">
#       <div class="flex flex-col">
#
#         <div class="text-34 md:text-42 xl:text-52 break-words mb-6">
#           «Мир после нас: Как не дать планете погибнуть»
#         </div>
#
#
#                   <div class="grid grid-cols-6 sm:grid-cols-7 items-center text-14 pt-1.5 sm:pt-6 mb-10 sm:mb-13 gap-y-10 gap-x-5 md:gap-x-9">
#             <div class="col-span-6 sm:col-span-3 gap-x-5 flex items-center">
#                               <a class="shrink-0 w-12 h-12" href="/author/alpina-pabliser">
#                   <img src="https://app-images.website.yandexcloud.net/694839/36720ef38be61db31217d1acaf157f36.jpg"
#                        loading="lazy"
#                        class="w-full h-full object-cover" alt="«Альпина Паблишер»">
#                 </a>
#                             <a class="text-14 flex flex-col" href="/author/alpina-pabliser">
#                 <span class="mb-0.5">
#
#                                     «Альпина Паблишер»
#                 </span>
#                 <span class="font-spectral text-main-gray">Книжное издательство</span>
#               </a>
#             </div>
#             <div class="col-span-6 sm:col-span-3 lg:col-start-5">
#               <p class="font-spectral text-main-gray">Мнение редакции может не совпадать с&nbsp;мнением автора</p>
#             </div>
#           </div>
#
#         <div class="text-14 pt-4 sm:pt-6 mb-10 sm:mb-12 flex flex-wrap">
#
#             <a class="underline whitespace-nowrap"
#                href="/author/alpina-pabliser">«Альпина Паблишер»</a>
#
#
#                   </div>
#
#         <div class="n1_material text-18">
#           <p class="mb-6">В конце XX века человечество задумалось, как обеспечить счастливое будущее потомкам, изменив подход к экономическому развитию — тогда же родилась идея устойчивого развития. Однако к настоящему моменту проблемы, обозначенные несколько десятков лет назад, все так же остаются неразрешенными. В книге «Мир после нас: Как не дать планете погибнуть» (издательство «Альпина Паблишер»), переведенной на русский язык Тамарой Эйдельман, доктор экономических наук Майя Гёпель рассказывает, почему так получилось и что значит осознанно подойти к пересмотру идей, структур и правил, на которых основана современная экономическая система. N + 1 предлагает своим читателям ознакомиться с отрывком, в котором рассказывается, почему рост благосостояния населения не поможет сократить вред, наносимый окружающей среде.</p>
#         </div>
#
#         <div class="mt-5 md:mt-6">
#           <a class="inline-flex justify-center bg-main w-full py-4"
#              href="https://nplus1.ru/blog/2021/09/28/unsere-welt-neu-denken">
#             <span class="text-white text-22 md:text-24">Читать дальше</span>
#           </a>
#         </div>
#
#       </div>
#     </div>
#
#   </div>
# </section>
#
#
#       <section class="mb-15 md:mb-20">
#       <div id="adfox_154408219501673625" class="bg-gray-100 w-full"></div>
#     </section>
#
#
#   <div class="mb-1 w-full overflow-hidden">
#     <app-material-slider-carousel :const-container="constContainer" :const-start-container="constStartContainer">
#   <template v-slot:default="slotProps">
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                                'padding-left': slotProps.left + 'px'
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/725921/639155084f149_hl_cover_v.jpeg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/725922/639155088cb68_hl_cover_h.jpeg">
#             <img src="https://app-images.website.yandexcloud.net/725922/639155088cb68_hl_cover_h.jpeg"
#                  style="background-color: #d4cac1"
#                  loading="lazy"
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="Директор школы из Узбекистана 29 лет пользовался 2000-летним сакским бронзовым котлом">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/news/2022/12/08">
#         <span class="group-hover:text-main transition-colors duration-75">08.12.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/876">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/1">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           1.9
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/news/2022/12/08/cauldron">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           Директор школы из Узбекистана 29 лет пользовался 2000-летним сакским бронзовым котлом</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             Теперь его передали в музей</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/727286/6396ea64a6690_hl_cover_v.jpg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/727287/6396ea64f2dbd_hl_cover_h.jpg">
#             <img src="https://app-images.website.yandexcloud.net/727287/6396ea64f2dbd_hl_cover_h.jpg"
#                  style="background-color: #857769"
#                  loading="lazy"
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="В свинцовом саркофаге из собора Парижской Богоматери обнаружили останки аристократа с распиленным черепом">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/news/2022/12/12">
#         <span class="group-hover:text-main transition-colors duration-75">12.12.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/876">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Археология
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/2">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           2.5
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/news/2022/12/12/notre-dame">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           В свинцовом саркофаге из собора Парижской Богоматери обнаружили останки аристократа с распиленным черепом</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             Он жил в XIV веке</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/728515/6398e768bc68b_hl_cover_v.jpg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/728516/6398e7690ef9e_hl_cover_h.jpg">
#             <img src="https://app-images.website.yandexcloud.net/728516/6398e7690ef9e_hl_cover_h.jpg"
#                  style="background-color: #72654e"
#                  loading="lazy"
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="В иммунных клетках современных папуасов нашли следы работы денисовской ДНК">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/news/2022/12/14">
#         <span class="group-hover:text-main transition-colors duration-75">14.12.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/877">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Антропология
#             </span>
#             </a>
#
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/difficulty/4">
#           <svg class="w-4 h-4 mr-1 group-hover:text-main transition-colors duration-75 stroke-current">
#             <use xlink:href="#n1_star"></use>
#           </svg>
#           <span class="group-hover:text-main transition-colors duration-75">
#           4.5
#         </span>
#         </a>
#       </div>
#
#
#       <a class="text-white absolute bottom-5 inset-x-4 md:inset-x-5 group"
#          href="https://nplus1.ru/news/2022/12/14/Denisovan-in-Papuans">
#         <p class="text-15 sm:text-24 lg:text-34 font-aeonik font-light  transition-colors duration-75 group-hover:text-main">
#           В иммунных клетках современных папуасов нашли следы работы денисовской ДНК</p>
#                   <p class="text-15 sm:text-24 lg:text-34 font-spectral font-light  transition-colors duration-75 group-hover:text-main">
#             А вот неандертальское наследие на активность генов не повлияло</p>
#               </a>
#
#
#
#     </div>
#
#   </div>
# </div>
#
#
#
#
#
#       <div class="absolute left-0 mr-1 box-content" :style="{'width': constWidthHorizontalsCard + 'px',
#                               }">
#   <div class="relative w-full flex relative w-full flex shrink-0 h-72 xl:h-88">
#
#     <div class="shrink-0 absolute inset-0 group bg-main">
#
#
#                   <picture>
#             <source media="(max-width: 1023px)" srcset="https://app-images.website.yandexcloud.net/726064/639190a9d6ed5_hl_cover_v.jpeg">
#             <source media="(min-width: 1024px)" srcset="https://app-images.website.yandexcloud.net/726065/639190aa1cb6e_hl_cover_h.jpeg">
#             <img src="https://app-images.website.yandexcloud.net/726065/639190aa1cb6e_hl_cover_h.jpeg"
#                  style="background-color: #18a611"
#                  loading="lazy"
#                  class="w-full h-full object-cover absolute inset-0 brightness-50"
#                  alt="Зоопарк алгоритмов">
#           </picture>
#
#
#
#
#
#
#
#     </div>
#     <div class="flex flex-col pb-10 sm:pb-5 text-22 sm:text-20">
#       <div class="flex flex-wrap pt-5 pb-5 gap-2 text-tags text-white absolute top-0 inset-x-5">
#
#         <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#            href="/material/2022/11/25">
#         <span class="group-hover:text-main transition-colors duration-75">25.11.22</span>
#         </a>
#
#                               <a class="relative before:block before:w-px before:bg-current before:h-4 before:absolute before:left-0 pl-2 flex inline-flex items-center group"
#                href="/search/empty/812">
#             <span
#             class="group-hover:text-main transition-colors duration-75">
#             Партнерский материал
#             </span>
#             </a>
#
#
# ...
#       <div class="order-3 sm:col-span-9 lg:col-span-5 sm:order-3 lg:order-6 mt-auto col-span-6 mb-10 lg:mb-0">
#         <ul class="flex gap-3 text-gray-2">
#           <li>
#             <a class="hover:text-main" href="https://t.me/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tg"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://vk.com/nplusone" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_vk"></use>
#               </svg>
#             </a>
#           </li>
#           <li>
#             <a class="hover:text-main" href="https://ok.ru/nplus1" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_ok"></use>
#               </svg>
#             </a>
#           </li>
#           <li class="w-12">
#             <a class="hover:text-main" href="https://twitter.com/nplusodin" target="_blank">
#               <svg class="w-12 h-12">
#                 <use xlink:href="#n1_tw"></use>
#               </svg>
#             </a>
#           </li>
#         </ul>
#       </div>
#     </div>
#   </div>
#
# </footer>
#
#
#
# </div>
#
#
# <svg id="n1_star" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      width="16" height="16"
#      viewBox="3 3 16 16" fill="none">
#   <path d="M11 5V17"/>
#   <path d="M6.75781 6.75781L15.2431 15.2431"/>
#   <path d="M17 11L5 11"/>
#   <path d="M15.2422 6.75781L6.75691 15.2431"/>
# </svg>
# <svg id="n1_person" class="stroke-current" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 50 50" fill="none">
#   <circle cx="25" cy="25" r="24.5"/>
#   <path d="M30.1897 30.3212C28.9483 29.9852 27.5345 29.7164 27.5345 28.5067C27.5345 27.8347 27.5 27.0618 28.2931 26.625C31.0172 25.0457 32.5 22.3911 32.1552 18.2581C31.8103 14.0578 29.2586 11 24.9828 11C20.7069 11 18.1552 14.0578 17.8103 18.2581C17.4655 22.3911 18.9138 25.0457 21.6724 26.625C22.4655 27.0618 22.431 27.8347 22.431 28.5067C22.431 29.7164 21.0172 29.9516 19.8103 30.3212C17.3966 30.9933 12.5 31.9005 12.5 36C16.431 36 33.569 36 37.5 36C37.4655 31.9005 32.6034 30.9933 30.1897 30.3212Z"
#         stroke-miterlimit="10"/>
# </svg>
# <svg id="n1_tg" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <path d="M16.3181 21.32H19.4961V30H20.7141V21.32H23.8921V20.2H16.3181V21.32ZM28.6969 30.084C30.3769 30.084 31.4269 29.286 31.8749 28.572L31.9589 30H33.0089V24.694H28.8789V25.814H31.8189V26.15C31.8189 27.886 30.5169 28.964 28.7109 28.964C26.6809 28.964 25.3369 27.368 25.3369 25.1C25.3369 22.832 26.6809 21.236 28.7389 21.236C30.2229 21.236 31.2729 22.034 31.6089 23.392H32.9109C32.5749 21.376 30.9369 20.116 28.7669 20.116C25.9249 20.116 24.0909 22.132 24.0909 25.1C24.0909 28.068 25.9809 30.084 28.6969 30.084Z"
#         class="fill-current"/>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
# </svg>
# <svg id="n1_vk" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M19.8015 30H21.2715L24.7995 20.2H23.5395L20.5575 28.558L17.5615 20.2H16.2735L19.8015 30ZM25.8768 30H27.0948V27.452L29.0408 25.254L32.3448 30H33.8008L29.9368 24.33L33.5208 20.2H32.0368L27.0948 25.758V20.2H25.8768V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_ok" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M25.2125 25.1C25.2125 22.216 23.2945 20.116 20.5365 20.116C17.7785 20.116 15.8605 22.216 15.8605 25.1C15.8605 27.984 17.7785 30.084 20.5365 30.084C23.2945 30.084 25.2125 27.984 25.2125 25.1ZM17.1065 25.1C17.1065 22.846 18.4925 21.236 20.5365 21.236C22.5805 21.236 23.9665 22.846 23.9665 25.1C23.9665 27.354 22.5805 28.964 20.5365 28.964C18.4925 28.964 17.1065 27.354 17.1065 25.1ZM26.7518 30H27.9698V27.452L29.9158 25.254L33.2198 30H34.6758L30.8118 24.33L34.3958 20.2H32.9118L27.9698 25.758V20.2H26.7518V30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_tw" style="display:block;width:0;height:0" viewBox="0 0 50 50" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <path d="M14.4792 21.32H17.6572V30H18.8752V21.32H22.0532V20.2H14.4792V21.32ZM25.332 30H26.788L29.014 22.23L31.254 30H32.71L35.58 20.2H34.32L32.01 28.432L29.686 20.2H28.454L26.046 28.432L23.75 20.2H22.476L25.332 30Z"
#         class="fill-current"></path>
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"></circle>
# </svg>
# <svg id="n1_infinity" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink" width="64px" height="64px" viewBox="0 0 100 100"
#      preserveAspectRatio="xMidYMid">
#   <path fill="none" stroke="#ffffff" stroke-width="5" stroke-dasharray="146.25568908691406 110.33323913574219"
#         d="M24.3 30C11.4 30 5 43.3 5 50s6.4 20 19.3 20c19.3 0 32.1-40 51.4-40 C88.6 30 95 43.3 95 50s-6.4 20-19.3 20C56.4 70 43.6 30 24.3 30z"
#         stroke-linecap="round" style="transform:scale(0.8);transform-origin:50px 50px">
#     <animate attributeName="stroke-dashoffset" repeatCount="indefinite" dur="1.3157894736842106s" keyTimes="0;1"
#              values="0;256.58892822265625"></animate>
#   </path>
# </svg>
# <svg id="n1_cross" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 14 14"
#      fill="none">
#   <path d="M1.00146 1L13.0015 13" stroke="#F9F9F9"/>
#   <path d="M13 1L1 13" stroke="#F9F9F9"/>
# </svg>
# <svg id="n1_link_arrow" style="display:block;width:0;height:0" viewBox="0 0 11 11" xmlns="http://www.w3.org/2000/svg">
#   <path d="M10.0738 5.87L5.08775 0.901999L4.15175 1.838L7.51775 5.204H0.19175V6.536H7.51775L4.15175 9.902L5.08775 10.838L10.0738 5.87Z"
#         fill="currentColor"></path>
# </svg>
# <svg id="n1_big_star" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 61 61">
#   <path class="fill-current" fill-rule="evenodd" clip-rule="evenodd"
#         d="M3 29.7729H29.0656L10.6345 11.3418L11.3416 10.6347L29.7728 29.0658V3H30.7728V29.0658L49.2039 10.6347L49.911 11.3418L31.4799 29.7729H57.5455V30.7729H31.4799L49.9111 49.2042L49.204 49.9113L30.7728 31.4801V57.5455H29.7728V31.4801L11.3415 49.9113L10.6344 49.2042L29.0656 30.7729H3V29.7729Z"/>
#   <path class="fill-current"
#         d="M29.0656 29.7729V32.2729H35.1012L30.8334 28.0052L29.0656 29.7729ZM3 29.7729V27.2729H0.5V29.7729H3ZM10.6345 11.3418L8.86676 9.57407L7.099 11.3418L8.86676 13.1096L10.6345 11.3418ZM11.3416 10.6347L13.1094 8.86696L11.3416 7.09919L9.57387 8.86696L11.3416 10.6347ZM29.7728 29.0658L28.005 30.8336L32.2728 35.1014V29.0658H29.7728ZM29.7728 3V0.5H27.2728V3H29.7728ZM30.7728 3H33.2728V0.5H30.7728V3ZM30.7728 29.0658H28.2728V35.1014L32.5405 30.8336L30.7728 29.0658ZM49.2039 10.6347L50.9716 8.86696L49.2039 7.09919L47.4361 8.86696L49.2039 10.6347ZM49.911 11.3418L51.6787 13.1096L53.4465 11.3418L51.6787 9.57407L49.911 11.3418ZM31.4799 29.7729L29.7121 28.0052L25.4443 32.2729H31.4799V29.7729ZM57.5455 29.7729H60.0455V27.2729H57.5455V29.7729ZM57.5455 30.7729V33.2729H60.0455V30.7729H57.5455ZM31.4799 30.7729V28.2729H25.4443L29.7121 32.5407L31.4799 30.7729ZM49.9111 49.2042L51.6789 50.972L53.4466 49.2042L51.6789 47.4364L49.9111 49.2042ZM49.204 49.9113L47.4362 51.6791L49.204 53.4468L50.9718 51.6791L49.204 49.9113ZM30.7728 31.4801L32.5405 29.7123L28.2728 25.4445V31.4801H30.7728ZM30.7728 57.5455V60.0455H33.2728V57.5455H30.7728ZM29.7728 57.5455H27.2728V60.0455H29.7728V57.5455ZM29.7728 31.4801H32.2728V25.4445L28.005 29.7123L29.7728 31.4801ZM11.3415 49.9113L9.57374 51.6791L11.3415 53.4468L13.1093 51.6791L11.3415 49.9113ZM10.6344 49.2042L8.86664 47.4364L7.09887 49.2042L8.86664 50.972L10.6344 49.2042ZM29.0656 30.7729L30.8334 32.5407L35.1012 28.2729H29.0656V30.7729ZM3 30.7729H0.5V33.2729H3V30.7729ZM29.0656 27.2729H3V32.2729H29.0656V27.2729ZM8.86676 13.1096L27.2979 31.5407L30.8334 28.0052L12.4023 9.57407L8.86676 13.1096ZM9.57387 8.86696L8.86676 9.57407L12.4023 13.1096L13.1094 12.4025L9.57387 8.86696ZM31.5405 27.2981L13.1094 8.86696L9.57387 12.4025L28.005 30.8336L31.5405 27.2981ZM27.2728 3V29.0658H32.2728V3H27.2728ZM30.7728 0.5H29.7728V5.5H30.7728V0.5ZM33.2728 29.0658V3H28.2728V29.0658H33.2728ZM32.5405 30.8336L50.9716 12.4025L47.4361 8.86696L29.005 27.2981L32.5405 30.8336ZM47.4361 12.4025L48.1432 13.1096L51.6787 9.57407L50.9716 8.86696L47.4361 12.4025ZM48.1432 9.57407L29.7121 28.0052L33.2476 31.5407L51.6787 13.1096L48.1432 9.57407ZM57.5455 27.2729H31.4799V32.2729H57.5455V27.2729ZM60.0455 30.7729V29.7729H55.0455V30.7729H60.0455ZM31.4799 33.2729H57.5455V28.2729H31.4799V33.2729ZM51.6789 47.4364L33.2476 29.0052L29.7121 32.5407L48.1433 50.972L51.6789 47.4364ZM50.9718 51.6791L51.6789 50.972L48.1433 47.4364L47.4362 48.1435L50.9718 51.6791ZM29.005 33.2478L47.4362 51.6791L50.9718 48.1435L32.5405 29.7123L29.005 33.2478ZM33.2728 57.5455V31.4801H28.2728V57.5455H33.2728ZM29.7728 60.0455H30.7728V55.0455H29.7728V60.0455ZM27.2728 31.4801V57.5455H32.2728V31.4801H27.2728ZM28.005 29.7123L9.57374 48.1435L13.1093 51.6791L31.5405 33.2478L28.005 29.7123ZM13.1093 48.1435L12.4022 47.4364L8.86664 50.972L9.57374 51.6791L13.1093 48.1435ZM12.4022 50.972L30.8334 32.5407L27.2979 29.0052L8.86664 47.4364L12.4022 50.972ZM3 33.2729H29.0656V28.2729H3V33.2729ZM0.5 29.7729V30.7729H5.5V29.7729H0.5Z"/>
# </svg>
# <svg id="n1_circle_arrow" style="display:block;width:0;height:0" class="stroke-current"
#      xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30" fill="none">
#   <rect x="29.5" y="29.5" width="29" height="29" rx="14.5" transform="rotate(-180 29.5 29.5)"/>
#   <path d="M9.33985 14.7014L14.6198 19.9414L15.2598 19.3014L11.1198 15.1614L20.3398 15.1614L20.3398 14.2214L11.1198 14.2214L15.2598 10.0814L14.6198 9.44141L9.33985 14.7014Z"/>
# </svg>
# <svg id="n1_circle_arrow_solid" style="display:block;width:0;height:0" xmlns="http://www.w3.org/2000/svg"
#      viewBox="0 0 30 30" fill="none">
#   <mask id="path-1-inside-1_2694_77554">
#     <path fill-rule="evenodd" clip-rule="evenodd"
#           d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"/>
#   </mask>
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M15 0C6.71573 0 0 6.71573 0 15C0 23.2843 6.71573 30 15 30C23.2843 30 30 23.2843 30 15C30 6.71573 23.2843 0 15 0ZM15.3792 10.0601L20.6592 15.3001L15.3792 20.5601L14.7392 19.9201L18.8792 15.7801H9.65918V14.8401H18.8792L14.7392 10.7001L15.3792 10.0601Z"
#         fill="#fff"/>
#   <path d="M20.6592 15.3001L21.3649 16.0085L22.0774 15.2987L21.3636 14.5903L20.6592 15.3001ZM15.3792 10.0601L16.0836 9.35027L15.3765 8.64853L14.6721 9.35295L15.3792 10.0601ZM15.3792 20.5601L14.6721 21.2672L15.3778 21.9729L16.0849 21.2685L15.3792 20.5601ZM14.7392 19.9201L14.0321 19.213L13.325 19.9201L14.0321 20.6272L14.7392 19.9201ZM18.8792 15.7801L19.5863 16.4872L21.2934 14.7801H18.8792V15.7801ZM9.65918 15.7801H8.65918V16.7801H9.65918V15.7801ZM9.65918 14.8401V13.8401H8.65918V14.8401H9.65918ZM18.8792 14.8401V15.8401H21.2934L19.5863 14.133L18.8792 14.8401ZM14.7392 10.7001L14.0321 9.99295L13.325 10.7001L14.0321 11.4072L14.7392 10.7001ZM1 15C1 7.26801 7.26801 1 15 1V-1C6.16344 -1 -1 6.16344 -1 15H1ZM15 29C7.26801 29 1 22.732 1 15H-1C-1 23.8366 6.16344 31 15 31V29ZM29 15C29 22.732 22.732 29 15 29V31C23.8366 31 31 23.8366 31 15H29ZM15 1C22.732 1 29 7.26801 29 15H31C31 6.16344 23.8366 -1 15 -1V1ZM21.3636 14.5903L16.0836 9.35027L14.6748 10.7698L19.9548 16.0098L21.3636 14.5903ZM16.0849 21.2685L21.3649 16.0085L19.9534 14.5916L14.6734 19.8516L16.0849 21.2685ZM14.0321 20.6272L14.6721 21.2672L16.0863 19.853L15.4463 19.213L14.0321 20.6272ZM18.1721 15.073L14.0321 19.213L15.4463 20.6272L19.5863 16.4872L18.1721 15.073ZM9.65918 16.7801H18.8792V14.7801H9.65918V16.7801ZM8.65918 14.8401V15.7801H10.6592V14.8401H8.65918ZM18.8792 13.8401H9.65918V15.8401H18.8792V13.8401ZM14.0321 11.4072L18.1721 15.5472L19.5863 14.133L15.4463 9.99295L14.0321 11.4072ZM14.6721 9.35295L14.0321 9.99295L15.4463 11.4072L16.0863 10.7672L14.6721 9.35295Z"
#         fill="#fff" mask="url(#path-1-inside-1_2694_77554)"/>
# </svg>
# <svg id="n1_play" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 50 50"
#      fill="none">
#   <circle cx="25" cy="25" r="24.5" class="stroke-current"/>
#   <path d="M18 35V15L36 25L18 35Z" class="stroke-current"/>
# </svg>
# <svg id="n1_pupa" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 23"
#      fill="none">
#   <path fill-rule="evenodd" clip-rule="evenodd"
#         d="M17 8.80329C17 13.0922 13.4392 16.6066 9 16.6066C4.56077 16.6066 1 13.0922 1 8.80329C1 4.51437 4.56077 1 9 1C13.4392 1 17 4.51437 17 8.80329ZM14.9967 15.3678C13.4049 16.7601 11.3035 17.6066 9 17.6066C4.02944 17.6066 0 13.6652 0 8.80329C0 3.94137 4.02944 0 9 0C13.9706 0 18 3.94137 18 8.80329C18 11.0562 17.1348 13.1114 15.7118 14.6684L23.3531 22.1427C23.5505 22.3358 23.554 22.6524 23.3609 22.8498C23.1678 23.0472 22.8513 23.0507 22.6539 22.8576L14.9967 15.3678Z"
#         fill="#32363A"/>
# </svg>
# <svg id="n1_burger" style="display:block;width:0;height:0;" viewBox="0 0 30 30" fill="none"
#      xmlns="http://www.w3.org/2000/svg">
#   <line y1="6.5" x2="30" y2="6.5" stroke="#32363A"/>
#   <line y1="23.5" x2="30" y2="23.5" stroke="#32363A"/>
#   <line y1="15" x2="30" y2="15" stroke="#32363A"/>
# </svg>
# <svg id="n1_cross_menu" style="display:block;width:0;height:0;" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 30 30"
#      fill="none">
#   <path d="M4 4L26 26" stroke="#32363A"/>
#   <path d="M26 4L4 26" stroke="#32363A"/>
# </svg>
# <svg id="n1_check" style="display:block;width:0;height:0;fill:currentColor" xmlns="http://www.w3.org/2000/svg"
#      version="1.1" viewBox="0 0 752 752">
#   <path d="m183.6 357.87-22.184 22.168v0.003907c-3.2969 3.293-3.2969 8.6367 0 11.934l133.29 133.28v0.003907c3.7305 3.7266 8.7891 5.8242 14.066 5.8242 5.2734 0 10.332-2.0977 14.062-5.8242l267.76-267.76c1.582-1.582 2.4727-3.7305 2.4727-5.9688 0-2.2383-0.89062-4.3867-2.4727-5.9688l-22.156-22.168c-1.582-1.5898-3.7344-2.4805-5.9727-2.4805-2.2422 0-4.3945 0.89062-5.9766 2.4805l-244.31 244.3c-1.8828 1.8789-4.9336 1.8789-6.8164 0l-109.84-109.83c-3.293-3.2852-8.625-3.2852-11.918 0z"/>
# </svg>
#
# <script src="/front-build/js/app.js?v=07122022"></script>
# <script src="/js/twitter/widgets.js"></script>
#
#   <!-- Yandex.Metrika counter 2-->
# <script type="text/javascript" >
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(88946384, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true
# });
#
#
# ym(29654565, "init", {
# 	clickmap:true,
# 	trackLinks:true,
# 	accurateTrackBounce:true,
# 	webvisor:true,
# 	trackHash:true,
# 	ecommerce:"dataLayer"
# });
# </script>
# <noscript>
#   <div>
#     <img src="https://mc.yandex.ru/watch/88946384" style="position:absolute; left:-9999px;" alt="" />
#     <img src="https://mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" />
#   </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=UA-61773772-1"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-61773772-1');
# </script>
#
#
#
#
# <script>
# if ('serviceWorker' in navigator) {
# 	window.addEventListener('load', () => {
# 		navigator.serviceWorker.register('/front-service-worker.js').then(reg => {
# 			// sometime later…
# 			reg.update()
# 		})
# 	})
# }
# </script>
#
#
#
#
#
# </body>
# </html>

# %% [markdown]
# Ответ содержит HTML-код страницы, к которой мы обратились.

# %% [markdown]
# *В отличие от предыдущего примера, где ответ возвращался в JSON-формате, мы не можем так просто преобразовать HTML-код в словарь и извлечь необходимую нам информацию.*

# %% [markdown]
# Для решения таких задач в Python существует специальная библиотека BeautifulSoup, о работе с которой мы поговорим в следующем юните.

# %% [markdown]
# #### <center>Библиотека BeautifulSoup

# %% [markdown]
# *✍ Для поиска необходимых нам данных мы будем использовать библиотеку BeautifulSoup, которая позволяет по названию тегов и их атрибутов получать содержащийся в них текст.*

# %% [markdown]
# BeautifulSoup не является частью стандартной библиотеки, поэтому для начала её нужно установить. Например, в Jupyter Notebook это делается с помощью такой команды:

# %%
# Устанавливаем библиотеку BeautifulSoup
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\konstantin\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.3.2.post1)

# %% [markdown]
# После установки импортируем библиотеку в наш код:

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %% [markdown]
# Теперь мы можем извлекать данные из любой веб-страницы.
#
# Ранее мы уже получили содержимое страницы с помощью GET-запроса и сохранили информацию в переменной response , теперь создадим объект BeautifulSoup с именем page, указывая в качестве параметра html.parser.
#
# Для примера получим информацию o title (с англ. заголовок) — это строка, которая отображается на вкладке браузера:

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# *Если при запросе к сайту, а затем при его разборе с помощью BeautifulSoup в тексте страницы не находится нужный тег, попробуйте вывести на печать пару тысяч символов текста страницы. Если там обнаружится нечто похожее на капчу, возможно, сайт посчитал вас роботом и отказывается выдавать содержимое. Чтобы получить его, попробуйте «притвориться» браузером при запросе из скрипта:*
#
# ```python
# requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
# ```
# *User-Agent своего браузера можно узнать по этой ссылке. http://n5m.ru/usagent.html*

# %% [markdown]
# #### <center>ИЗВЛЕКАЕМ ЗАГОЛОВОК И ВРЕМЯ НАПИСАНИЯ СТАТЬИ

# %% [markdown]
# Выполним поставленную ранее задачу: получить информацию о странице и извлечь заголовок статьи https://nplus1.ru/news/2021/10/11/econobel2021, опубликованной на этой странице, дату публикации, а также текст статьи.
#
# Предположим, что мы знаем, что в HTML-коде рассматриваемой нами страницы заголовок статьи заключён в тег **<*h1*>** … **<*/h1*>** (заголовок первого уровня).
#
# Тогда мы можем получить его текст с помощью метода find() (с англ. найти) объекта BeautifulSoup, передав ему название интересующего нас тега:

# %%
print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
# Out:
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %% [markdown]
# ? Но как же узнать, в каких именно тегах заключена необходимая информация?

# %% [markdown]
# Проще всего это сделать с помощью так называемого инструмента разработчика, который есть во всех современных браузерах. Покажем, как открыть данный инструмент на примере использования браузера Google Chrome.
#
# Устанавливаем курсор на элементе страницы https://nplus1.ru/news/2021/10/11/econobel2021https://nplus1.ru/news/2021/10/11/econobel2021  (заголовок статьи), информацию о котором хотим получить, нажимаем на правую клавишу мыши и в выпадающем списке выбираем пункт «Просмотреть код элемента» или «Посмотреть код» в зависимости от браузера.
#
# ![Код](data/Python_17_8.png "Код")

# %% [markdown]
# В открывшемся окне инструмента разработчика видим, что информация о заголовке статьи заключена в теге **<*h1*>** … **<*/h1*>**.
#
# ![Заголовок](data/Python_17_9.png "Заголовок")

# %% [markdown]
# Аналогично получим информации о теге, который содержит дату написания статьи, отображаемую в левом верхнем углу страницы.
#
# ![Тэг](data/Python_17_10.png "Тэг")

# %% [markdown]
# Итак, нам нужен тег **<*span*>** … **<*/span*>**.
#
# Теперь получим данные из него с помощью уже известного метода find(), передав название нужного тега:

# %%
print(page.find('span').text) # Выводим на экран содержимое атрибута text тега span
# Out:
# 13:04

# %% [markdown]
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.
#
# Функция wiki_header принимает один аргумент - url.

# %%
#import requests # Импортируем библиотеку requests
#from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
def wiki_header(url):
    page=BeautifulSoup(requests.get(url).text,'html.parser')
    header=page.find('h1').text
    return header
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
print(wiki_header(url = 'https://en.wikipedia.org/wiki/Operating_system'))
# Out:
# Operating system

# %% [markdown]
# #### <center>НЕУНИКАЛЬНЫЕ ТЕГИ: ИЗВЛЕКАЕМ ТЕКСТ СТАТЬИ

# %% [markdown]
# Теперь получим сам текст статьи. Как вы уже знаете, первым делом необходимо определить, в какой тег он заключён. Применим, как и ранее, инструмент разработчика.
#
# ![Текст](data/Python_17_12.png "Текст")

# %% [markdown]
# Видим, что искомый текст заключён в тег  **<*div*>** … **<*/div*>** . Попробуем извлечь его уже известным нам способом — с помощью метода find() — и выведем его на экран.

# %%
print(page.find('div').text) # Выводим содержимое атрибута text тега div
# Out:
# N + offline
# N + production
#
#
#
#
#                 О нас
#
#
#                 Сложность
#
#
#                 Рекламодателям
#
#
#                 Авторам
#
#
#
# Физика
# Зоология
# Астрономия
# Генетика
# Математика
# Космонавтика
#
#
# Археология
# Нейронауки
# На мышах
# Звук
# Красота
# Научные закрытия
#
#
# ИИ спешит на помощь
# Когда рассеется дым
# Книжная полка
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# О
#           нас
# Сложность
# Рекламодателям
# Вакансии
#
#
# Физика
# Зоология
# Астрономия
# Генетика
# Математика
# Космонавтика
# Археология
# Нейронауки
# На мышах
# Звук
# Красота
# Научные закрытия
# ИИ спешит на помощь
# Когда рассеется дым
# Книжная полка
#
#
#
# N + offline
# N + production
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 13:04
#
#
# 11.10.21
#
#
#
#
#
# 1.1
#
#
# Экономика
#
#
# Нобелевская премия
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#
#
#
# Илья Ферапонтов
#
#
#
#
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.
#
# Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.
# Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.
# Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.
# Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году предположила, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.
# Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.
# В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале «Тонкости молотка».
# В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале «Опыты на бедных». В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале «Почем знания для природы».
# Сергей Кузнецов
#
#
#
#               Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 28.09.21
#
#
#
#
#
# 1.1
#
#
# Ex libris
#
#
# Экономика
#
#
# Книжная полка
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           «Мир после нас: Как не дать планете погибнуть»
#
#
#
#
#
#
#
#
#
#                                     «Альпина Паблишер»
#
# Книжное издательство
#
#
#
# Мнение редакции может не совпадать с мнением автора
#
#
#
# «Альпина Паблишер»
#
#
# В конце XX века человечество задумалось, как обеспечить счастливое будущее потомкам, изменив подход к экономическому развитию — тогда же родилась идея устойчивого развития. Однако к настоящему моменту проблемы, обозначенные несколько десятков лет назад, все так же остаются неразрешенными. В книге «Мир после нас: Как не дать планете погибнуть» (издательство «Альпина Паблишер»), переведенной на русский язык Тамарой Эйдельман, доктор экономических наук Майя Гёпель рассказывает, почему так получилось и что значит осознанно подойти к пересмотру идей, структур и правил, на которых основана современная экономическая система. N + 1 предлагает своим читателям ознакомиться с отрывком, в котором рассказывается, почему рост благосостояния населения не поможет сократить вред, наносимый окружающей среде.
#
#
#
# Читать дальше
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# О нас
#
#
# Сложность
#
#
# Рекламодателям
#
#
# Авторам
#
#
#
# © 2022 N + 1 Интернет-издание / Свидетельство о регистрации СМИ Эл № ФС77-67614
#
#
# Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на N + 1.Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются только в образовательных и информационных целях.Если вы являетесь собственником того или иного произведения и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru
# Связь с редакцией: info@nplus1.ru
#
#
# Политика
#           обработки
#           персональных данных пользователей сайта

# %% [markdown]
# Мы увидели не то, что ожидали — кучу текста, не имеющего отношения к тому, что мы искали...
#
# ? В чём же проблема?

# %% [markdown]
# Дело в том, что теги **<*div*>** … **<*/div*>** очень распространённые и на странице их очень много. Метод find() нашёл первый из них, но это не то, что нам надо.

# %% [markdown]
# Посмотрим на нашу страницу, используя инструмент разработчика, ещё раз. Можем заметить, что у искомого текста есть свой класс — n1_material text-18 :
#
# ![Класс](data/Python_17_14.png "Класс")

# %% [markdown]
# Передадим название класса в метод find() с помощью аргумента class_ и получим текст статьи:

# %%
print(page.find('div', class_='n1_material text-18').text) # Выводим содержимое атрибута text тега div класса n1_material text-18
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.

# %% [markdown]
# В данном случае происходит поиск точного строкового значения class атрибута, т. е. выполнение строк кода:
#
# ```python
# print(page.find('div', class_='n1_material').text)
# ```
# ```python
# print(page.find('div', class_='n1_material text-18').text)
# ```
# даст одинаковый результат.

# %% [markdown]
# При выполнении строки кода

# %%
print(page.find('div', class_='text-18 n1_material').text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 print(page.find('div', class_='text-18 n1_material').text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# мы получим ошибку, так как такого строкового значения в области поиска нет.

# %% [markdown]
# О поиске по классу можно узнать подробнее в Beautiful Soup Documentation https://www.crummy.com/software/BeautifulSoup/bs4/doc/#searching-by-css-class.

# %% [markdown]
# Задача решена — мы извлекли из контента страницы заголовок статьи, опубликованной на странице, дату публикации, а также текст статьи.

# %% [markdown]
# #### <center>СБОР НЕСКОЛЬКИХ ЭЛЕМЕНТОВ: СОБИРАЕМ ВСЕ ССЫЛКИ НА СТРАНИЦЕ

# %% [markdown]
# Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в Wikipedia https://en.wikipedia.org/wiki/List_of_programming_languages в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег **<*a*>** … **<*/a*>**. Попробуем использовать find():

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %% [markdown]
# Мы получили только одну ссылку, хотя на странице их явно больше.

# %% [markdown]
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

# %%
links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 942

# %% [markdown]
# Итак, на момент создания этих учебных материалов на странице содержалось 942 ссылок. Посмотрим на некоторые из них:

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
# Out:
# ['Opal', 'Open Programming Language', 'OpenCL', 'OpenEdge Advanced Business Language', 'OpenVera', 'OpenQASM', 'OPS5', 'OptimJ', 'Orc', 'ORCA/Modula-2']

# %% [markdown]
# Не все ссылки соответствуют названиям языков программирования — страница содержит также «служебные» ссылки, такие, например, как Jump to navigation (с англ. Перейти к навигации) или Alphabetical (с англ. По алфавиту):

# %%
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['', 'Jump to navigation', 'Jump to search', 'Programming languagelists', 'Alphabetical', 'Categorical', 'Chronological', 'Generational', 'v', 't']

# %% [markdown]
# Для обработки полученных данных и исключения «лишней» информации можно, например, использовать подходы, которые вы изучили в модуле PYTHON-14 https://lms.skillfactory.ru/courses/course-v1:SkillFactory+DST-3.0+28FEB2021/jump_to_id/c988abcb7a6d4ebeb22cf03b00e8118e.

# %% [markdown]
# *✍ В заключение заметим, что BeautifulSoup — достаточно мощная библиотека. Мы рассмотрели её базовые возможности, но их полный список гораздо шире. С ним можно ознакомиться в официальной документации https://www.crummy.com/software/BeautifulSoup/bs4/doc/.*

# %% [markdown]
# #### <center>Работа с API

# %% [markdown]
# *✍ В предыдущих разделах мы собирали полезную информацию с различных сайтов.*
#
# *Вы могли убедиться, что поиск необходимой информации с выделением правильных тегов — довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка или владельцы сайтов защищаются от ботов капчей (Ка́пча (от CAPTCHA — англ. Completely Automated Public Turing test to tell Computers and Humans Apart — полностью автоматизированный публичный тест Тьюринга для различения компьютеров и людей) — компьютерный тест, используемый для того, чтобы определить, кем является пользователь системы: человеком или компьютером.*
#
# *Термин «Капча» появился в 2000 году. Основная идея теста: предложить пользователю такую задачу, которая с лёгкостью решается человеком, но крайне сложна и трудоёмка для компьютера. По состоянию на 2013 год, каждый день пользователями по всей планете вводится примерно 320 миллионов «капчей»).*

# %% [markdown]
# К счастью, многие крупные сайты предоставляют доступ к так называемым **API** (англ. Application Programming Interface, рус. Интерфейс Прикладного Программирования).

# %% [markdown]
# *API — это специальные разделы сайта, где информацию можно получать без разметки, а формат запросов и ответов зафиксирован. API созданы для того, чтобы облегчить взаимодействие с сайтом для сторонних разработчиков.*

# %% [markdown]
# К примеру, мы уже видели, как ресурс Курсы валют ЦБ РФ в XML и JSON https://www.cbr-xml-daily.ru/ возвращает данные о валютах в JSON-формате. Это пример API.
#
# Рассмотрим на примере социальной сети ВКонтакте особенности API, характерные для более крупных сайтов.

# %% [markdown]
# #### <center>КЛЮЧ АВТОРИЗАЦИИ

# %% [markdown]
# Для того чтобы начать работать с API, обычно необходимо получить сервисный ключ авторизации — **токен**.

# %% [markdown]
# **Токен** *— это средство идентификации пользователя или отдельного сеанса работы в компьютерных сетях и приложениях. Различают **программные** и **аппаратные** токены.*
# *Мы будем использовать программный токен, который обычно представляет собой зашифрованную последовательность символов, позволяющую точно идентифицировать объект и определить уровень его привилегий. Он генерируется системой авторизации и привязывается к конкретному сеансу работы, клиенту сети или пакету данных.*

# %% [markdown]
# Авторизация применяется практически во всех API, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени.
#
# Сервисный токен для API ВКонтакте для нашей задачи создаётся вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на страницу https://vk.com/editapp?act=create, чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и в разделе Платформа поставьте отметку выбора напротив значения Standalone-приложение:
#
# ![ВК](data/Python_17_22.jpg "ВК")

# %% [markdown]
# У меня нет аккаунта в ВК. Что делать?
# В отличие от многих других социальных сетей, ВК предоставляет API для парсинга данных — это открывает огромные возможности для аналитиков и дата-сайентистов. На хакатонах порой бывают задачи найти какие-то интересные закономерности именно в информации из ВК.
#
# Для работы с данными этой социальной сети достаточно создать базовый профиль с минимумом личной информации, а при регистрации потребуется ввести только номер телефона и адрес электронной почты.
#
# Безусловно, регистрация в ВК — ваше личное дело. Однако, отказавшись от неё, вы лишите себя возможности исследовать огромные объёмы актуальных данных.

# %% [markdown]
# Подтвердив создание приложения на сайте в приложении ВКонтакте или по СМС, зайдите в **Настройки**. Нужный нам токен лежит в поле **Сервисный ключ доступа**:
#
# ![Ключ](data/Python_17_23.jpg "Ключ")

# %% [markdown]
# #### <center>ПЕРВЫЕ ЗАПРОСЫ К API

# %% [markdown]
# Чтобы познакомиться с работой API, мы будем получать данные для статистических отчётов произвольной группы, например данные о соотношении мужчин и женщин, статистику географии пользователей и т. п.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Сделаем наш первый запрос из браузера.
#
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова TOKEN ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:
#
# ```python
# https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=TOKEN
# ```

# %% [markdown]
# *Примечание: адресная строка в браузере будет выглядеть примерно так:  https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=8b3341297d3341297d334129917d5e4be377d337d33412920ba951f8120284cd53ff3bd*

# %% [markdown]
# Результат:
#
# ```python
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}
# ```

# %% [markdown]
# Итак, мы сделали GET-запрос к API ВКонтакте, который состоит из следующих элементов:
#
# * https://api.vk.com/method — домен и URL запроса API; обычно не меняется;
# * users.get — название метода, который отдаёт определённый отчёт, в нашем случае это метод для получения информации о пользователе;
# * user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию (в нашем примере мы запрашиваем информацию о первом пользователе), и номер версии API;
# * token — токен, который выдаётся только пользователям, имеющим право просматривать определённые данные, например показания счётчиков Яндекс.Метрики вашего проекта; на все остальные запросы без корректного токена система отвечает отказом.

# %% [markdown]
# Если мы обратимся к документации метода users.get https://vk.com/dev/users.get, то увидим, что в ней описано множество других параметров, которые можно получить о пользователе (дата рождения, пол, родной город и другие) — словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал).

# %% [markdown]
# Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):
#
# ```python
# https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=TOKEN
# ```

# %% [markdown]
# Результат:
#
# ```python
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}
# ```

# %% [markdown]
# *Примечание: значение 2 у параметра sex означает мужской пол.*

# %% [markdown]
# До этого момента мы делали запросы в браузере — теперь давайте выполним запросы из кода.

# %% [markdown]
# #### <center>ЗАПРОС К API ИЗ КОДА

# %% [markdown]
# Продолжаем пользоваться всё той же библиотекой requests.

# %%
import requests # Импортируем модуль requests
token = '1ae784861ae784861ae784867919f59a0511ae71ae7848679514694f6989ac734dc4739' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры
                                                                                               # нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# Мы получили строку в JSON-формате, которую можно преобразовать в словарь с помощью метода json(), после чего можно с лёгкостью обращаться к различным полям.

# %% [markdown]
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.

# %% [markdown]
# Попробуем это сделать:

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь
                                                                  # и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.

# %%
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
users500 = requests.get(url, params=params).json()['response']
users500
# Out:
# [{'id': 1,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Дуров',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 2,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Владимирова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 3,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 4,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 5,
#   'sex': 2,
#   'first_name': 'Илья',
#   'last_name': 'Перекопский',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 6,
#   'sex': 2,
#   'first_name': 'Николай',
#   'last_name': 'Дуров',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 7,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Кобылянский',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 8,
#   'sex': 2,
#   'first_name': 'Аки',
#   'last_name': 'Сепиашвили',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 9,
#   'sex': 1,
#   'first_name': 'Настя',
#   'last_name': 'Васильева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 10,
#   'sex': 2,
#   'first_name': 'Александр',
#   'last_name': 'Кузнецов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 11,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Петров',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 12,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 13,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 14,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Городецкий',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 15,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Васильков',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 16,
#   'sex': 1,
#   'first_name': 'Виктория',
#   'last_name': 'Беспалова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 17,
#   'sex': 2,
#   'first_name': 'Александр',
#   'last_name': 'Беспалов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 18,
#   'sex': 2,
#   'first_name': 'Симон',
#   'last_name': 'Кречмер',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 19,
#   'sex': 1,
#   'first_name': 'Светочек',
#   'last_name': 'Аленький',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 20,
#   'sex': 2,
#   'first_name': 'Илья',
#   'last_name': 'Турпиашвили',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 21,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Равдоникас',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 22,
#   'sex': 2,
#   'first_name': 'Семен',
#   'last_name': 'Воронин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 23,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Столбовский',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 24,
#   'sex': 2,
#   'first_name': 'Рамми',
#   'last_name': 'Цицуашвили',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 25,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Ведущенко',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 26,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 27,
#   'sex': 1,
#   'first_name': 'Юлия',
#   'last_name': 'Семиколенова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 28,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 29,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 30,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 31,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 32,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 33,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 34,
#   'sex': 1,
#   'first_name': 'Татьяна',
#   'last_name': 'Плуталова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 35,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 36,
#   'sex': 2,
#   'first_name': 'Иван',
#   'last_name': 'Смирнов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 37,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Казекин',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 38,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 39,
#   'sex': 2,
#   'first_name': 'David',
#   'last_name': 'Mirelli',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 40,
#   'sex': 2,
#   'first_name': 'Олег',
#   'last_name': 'Чередников',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 41,
#   'sex': 2,
#   'first_name': 'Владислав',
#   'last_name': 'Миллер',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 42,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Маркин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 43,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 44,
#   'sex': 1,
#   'first_name': 'Тамара',
#   'last_name': 'Мирилашвили',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 45,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Сергей',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 46,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Лесохин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 47,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Габриел',
#   'last_name': 'Шалел'},
#  {'id': 48,
#   'sex': 2,
#   'first_name': 'Миша',
#   'last_name': 'Мельников',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 49,
#   'sex': 2,
#   'first_name': 'Бот',
#   'last_name': 'Мороз',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 50,
#   'sex': 1,
#   'first_name': 'Снегурочка',
#   'last_name': 'Морозова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 51,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 52,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Вознесенский',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 53,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 54,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Фуртикова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 55,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Смирнов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 56,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Чернышев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 57,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'Сергей',
#   'last_name': 'Владимиров'},
#  {'id': 58,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Александр',
#   'last_name': 'Ковалев'},
#  {'id': 59,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Желудкова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 60,
#   'sex': 2,
#   'first_name': 'Даниэль',
#   'last_name': 'Розенберг',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 61,
#   'sex': 2,
#   'first_name': 'Григорий',
#   'last_name': 'Конрадт',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 62,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Ланина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 63,
#   'sex': 2,
#   'first_name': 'Никита',
#   'last_name': 'Поликарпов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 64,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 65,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Mikhail',
#   'last_name': 'Torline'},
#  {'id': 66,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 67,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 68,
#   'sex': 1,
#   'first_name': 'Вика',
#   'last_name': 'Мирилашвили',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 69,
#   'sex': 2,
#   'first_name': 'Avi',
#   'last_name': 'Shalel',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 70,
#   'sex': 2,
#   'first_name': 'Митя',
#   'last_name': 'Миронов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 71,
#   'sex': 1,
#   'first_name': 'Людмила',
#   'last_name': 'Романченко',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 72,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 73,
#   'sex': 1,
#   'first_name': 'Надежда',
#   'last_name': 'Лебедева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 74,
#   'sex': 1,
#   'first_name': 'Наташа',
#   'last_name': 'Филимонова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 75,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Копылова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 76,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'David',
#   'last_name': 'Biniaurischwili'},
#  {'id': 77,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 78,
#   'sex': 1,
#   'first_name': 'Anna',
#   'last_name': 'Rudneva',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 79,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Давид',
#   'last_name': 'Спектер'},
#  {'id': 80,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 81,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Влад',
#   'last_name': 'Куценко'},
#  {'id': 82,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Tami',
#   'last_name': 'Shalel'},
#  {'id': 83,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Дмитрий',
#   'last_name': 'Тихомиров'},
#  {'id': 84,
#   'sex': 2,
#   'first_name': 'Фёдор',
#   'last_name': 'Медведев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 85,
#   'sex': 2,
#   'first_name': 'Mikhail',
#   'last_name': 'Gennadevich',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 86,
#   'sex': 2,
#   'first_name': 'Никита',
#   'last_name': 'Пиастро',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 87,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 88,
#   'sex': 1,
#   'first_name': 'Полина',
#   'last_name': 'Олейник',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 89,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 90,
#   'sex': 1,
#   'first_name': 'Малина',
#   'last_name': 'Baci',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 91,
#   'sex': 1,
#   'first_name': 'Дарья',
#   'last_name': 'Белинская',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 92,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Тихонова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 93,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Забоева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 94,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Теплова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 95,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 96,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 97,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 98,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 99,
#   'sex': 1,
#   'first_name': 'Наталья',
#   'last_name': 'Брагина',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 100,
#   'sex': 1,
#   'first_name': 'Администрация ВКонтакте',
#   'last_name': '',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 101,
#   'sex': 0,
#   'first_name': 'Администратор',
#   'last_name': '',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 102,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Тенева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 103,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Романцева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 104,
#   'sex': 1,
#   'first_name': 'Ольга',
#   'last_name': 'Ребикова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 105,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Roman',
#   'last_name': 'Ponomarenko'},
#  {'id': 106,
#   'sex': 2,
#   'first_name': 'Спотти',
#   'last_name': 'Космический',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 107,
#   'sex': 1,
#   'first_name': 'Администрация',
#   'last_name': 'Б.',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 108,
#   'sex': 1,
#   'first_name': 'Диана',
#   'last_name': 'Курбатова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 109,
#   'sex': 1,
#   'first_name': 'Ольга',
#   'last_name': 'Горюнова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 110,
#   'sex': 2,
#   'first_name': 'Администрация',
#   'last_name': 'В.',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 111,
#   'sex': 1,
#   'first_name': 'Евгения',
#   'last_name': 'Лаврова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 112,
#   'sex': 1,
#   'first_name': 'Евгения',
#   'last_name': 'Алексеева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 113,
#   'sex': 2,
#   'first_name': 'Владислав',
#   'last_name': 'Умнов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 114,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 115,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 116,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 117,
#   'sex': 2,
#   'first_name': 'Антон',
#   'last_name': 'Краснов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 118,
#   'sex': 1,
#   'first_name': 'Светлана',
#   'last_name': 'Никулина',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 119,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 120,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Соколова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 121,
#   'sex': 1,
#   'first_name': 'Надежда',
#   'last_name': 'Сторчевая',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 122,
#   'sex': 1,
#   'first_name': 'Надежда',
#   'last_name': 'Игошина',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 123,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 124,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Горбунова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 125,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 126,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 127,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 128,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 129,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 130,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 131,
#   'sex': 2,
#   'first_name': 'Шурикен',
#   'last_name': 'Картошкин',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 132,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 133,
#   'sex': 2,
#   'first_name': 'Николай',
#   'last_name': 'Харчев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 134,
#   'sex': 2,
#   'first_name': 'Илико',
#   'last_name': 'Шаптай',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 135,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Филатова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 136,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 137,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 138,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Рощин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 139,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Роман',
#   'last_name': 'Чистяков'},
#  {'id': 140,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 141,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Михайлов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 142,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 143,
#   'sex': 1,
#   'first_name': 'Машечка',
#   'last_name': 'Зайцева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 144,
#   'sex': 2,
#   'first_name': 'Oleg',
#   'last_name': 'Zinkevich',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 145,
#   'sex': 2,
#   'first_name': 'Константин',
#   'last_name': 'Теплов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 146,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Муромцева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 147,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 148,
#   'sex': 2,
#   'first_name': 'Артём',
#   'last_name': 'Абанин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 149,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Лобакин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 150,
#   'sex': 1,
#   'first_name': 'Луиза',
#   'last_name': 'Левиева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 151,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Леонид',
#   'last_name': 'Добронов'},
#  {'id': 152,
#   'sex': 1,
#   'first_name': 'Илара',
#   'last_name': 'Юнаева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 153,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 154,
#   'sex': 2,
#   'first_name': 'Елисей',
#   'last_name': 'Замахов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 155,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Dennis',
#   'last_name': 'Yurlov'},
#  {'id': 156,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 157,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 158,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Владислав',
#   'last_name': 'Гатилов'},
#  {'id': 159,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 160,
#   'sex': 2,
#   'first_name': 'Васильев',
#   'last_name': 'Сергеевич',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 161,
#   'sex': 1,
#   'first_name': 'Валентина',
#   'last_name': 'Савосина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 162,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Аленичева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 163,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Романько',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 164,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Ткаченко',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 165,
#   'sex': 2,
#   'first_name': 'Иван',
#   'last_name': 'Романько',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 166,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Коменденко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 167,
#   'sex': 2,
#   'first_name': 'Демид',
#   'last_name': 'Кириленко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 168,
#   'sex': 1,
#   'first_name': 'Вероника',
#   'last_name': 'Кириленко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 169,
#   'sex': 1,
#   'first_name': 'Ольга',
#   'last_name': 'Чистоклетова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 170,
#   'sex': 2,
#   'first_name': 'Богдан',
#   'last_name': 'Жидков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 171,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 172,
#   'sex': 2,
#   'first_name': 'Aleksei',
#   'last_name': 'Gorodetskii',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 173,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Чепурная',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 174,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 175,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Захаренков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 176,
#   'sex': 2,
#   'first_name': 'Иван',
#   'last_name': 'Смирнов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 177,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Абраменко',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 178,
#   'sex': 1,
#   'first_name': 'Марья',
#   'last_name': 'Безносова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 179,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 180,
#   'sex': 2,
#   'first_name': 'Владимир',
#   'last_name': 'Корнев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 181,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'last_name': 'Матвеев'},
#  {'id': 182,
#   'sex': 2,
#   'first_name': 'Николай',
#   'last_name': 'Андреев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 183,
#   'sex': 1,
#   'first_name': 'Ольга',
#   'last_name': 'Кретова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 184,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Владимирова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 185,
#   'sex': 2,
#   'first_name': 'Вадим',
#   'last_name': 'Рудковский',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 186,
#   'sex': 1,
#   'first_name': 'Ольга',
#   'last_name': 'Савинкина-Титова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 187,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Сергей',
#   'last_name': 'Воскресенкий'},
#  {'id': 188,
#   'sex': 2,
#   'first_name': 'Евгений',
#   'last_name': 'Лыков',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 189,
#   'sex': 1,
#   'first_name': 'Вероника',
#   'last_name': 'Лежнева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 190,
#   'sex': 2,
#   'first_name': 'Вадим',
#   'last_name': 'Колосов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 191,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Гена',
#   'last_name': 'Загальский'},
#  {'id': 192,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 193,
#   'sex': 2,
#   'first_name': 'Иван',
#   'last_name': 'Кораблев-Дайсон',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 194,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Гребнев',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 195,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Келим',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 196,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Караваева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 197,
#   'sex': 1,
#   'first_name': 'Дарья',
#   'last_name': 'Бондаренко',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 198,
#   'sex': 2,
#   'first_name': 'Вальтер',
#   'last_name': 'Киршнер',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 199,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Жигалова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 200,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Стрельников',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 201,
#   'sex': 2,
#   'first_name': 'Игнатий',
#   'last_name': 'Дьяков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 202,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Максим',
#   'last_name': 'Ластовка'},
#  {'id': 203,
#   'sex': 1,
#   'first_name': 'Зоя',
#   'last_name': 'Барабанова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 204,
#   'sex': 1,
#   'first_name': 'Юлия',
#   'last_name': 'Скрябина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 205,
#   'sex': 1,
#   'first_name': 'Ирина',
#   'last_name': 'Ямщикова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 206,
#   'sex': 2,
#   'first_name': 'Юрий',
#   'last_name': 'Скрелин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 207,
#   'sex': 1,
#   'first_name': 'Yulia',
#   'last_name': 'Bekmukhamedova',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 208,
#   'sex': 2,
#   'first_name': 'Гена',
#   'last_name': 'Зарохин',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 209,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Дьячкова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 210,
#   'sex': 1,
#   'first_name': 'Аня',
#   'last_name': 'Дормидонтова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 211,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 212,
#   'sex': 1,
#   'first_name': 'Алёна',
#   'last_name': 'Фёдорова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 213,
#   'sex': 2,
#   'first_name': 'Максим',
#   'last_name': 'Казанский',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 214,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Зелёный',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 215,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Мерзлякова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 216,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'last_name': 'Мирных'},
#  {'id': 217,
#   'sex': 2,
#   'first_name': 'Alexander',
#   'last_name': 'Nasyrov',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 218,
#   'sex': 1,
#   'first_name': 'Oksana',
#   'last_name': 'Zotova',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 219,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Роман',
#   'last_name': 'Акамёлков'},
#  {'id': 220,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 221,
#   'sex': 1,
#   'first_name': 'Наталья',
#   'last_name': 'Курчакова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 222,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Ступина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 223,
#   'sex': 1,
#   'first_name': 'Инга',
#   'last_name': 'Гладущик',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 224,
#   'sex': 1,
#   'first_name': 'Ирина',
#   'last_name': 'Кирсанова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 225,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Петропавловская',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 226,
#   'sex': 2,
#   'first_name': 'Антон',
#   'last_name': 'Нестеров',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 227,
#   'sex': 1,
#   'first_name': 'Ася',
#   'last_name': 'Лазо',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 228,
#   'sex': 2,
#   'first_name': 'Дима',
#   'last_name': 'Мартиросов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 229,
#   'sex': 2,
#   'first_name': 'Гумер',
#   'last_name': 'Исаев',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 230,
#   'sex': 1,
#   'first_name': 'Олеся',
#   'last_name': 'Дигина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 231,
#   'sex': 2,
#   'first_name': 'Юрий',
#   'last_name': 'Бычков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 232,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 233,
#   'sex': 1,
#   'first_name': 'Варя',
#   'last_name': 'Баранова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 234,
#   'sex': 1,
#   'first_name': 'Julia',
#   'last_name': 'Traub',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 235,
#   'sex': 2,
#   'first_name': 'Фредерик',
#   'last_name': 'Булгаков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 236,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Насекина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 237,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Журавлёв',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 238,
#   'sex': 1,
#   'first_name': 'Татьяна',
#   'last_name': 'Тимофеева',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 239,
#   'sex': 1,
#   'first_name': 'Светлана',
#   'last_name': 'Степанова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 240,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Влад',
#   'last_name': 'Коробейников'},
#  {'id': 241,
#   'sex': 1,
#   'first_name': 'Наташа',
#   'last_name': 'Власова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 242,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Ёжиков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 243,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Лапанович',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 244,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Колдунова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 245,
#   'sex': 2,
#   'first_name': 'Zhenechka',
#   'last_name': 'Pimenofffffff',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 246,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Попов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 247,
#   'sex': 1,
#   'first_name': 'Юлия',
#   'last_name': 'Гордеева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 248,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Рейнгольд',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 249,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Карпова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 250,
#   'sex': 2,
#   'first_name': 'Юрий',
#   'last_name': 'Бабаин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 251,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Чудотворов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 252,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Микушев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 253,
#   'sex': 2,
#   'first_name': 'Karina',
#   'last_name': 'Mutlu',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 254,
#   'sex': 1,
#   'first_name': 'Ася',
#   'last_name': 'Щёголь',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 255,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Уласень',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 256,
#   'sex': 1,
#   'first_name': 'Ксения',
#   'last_name': 'Тинсли',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 257,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Саша',
#   'last_name': 'Дроздовский'},
#  {'id': 258,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 259,
#   'sex': 1,
#   'first_name': 'Катерина',
#   'last_name': 'Албу',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 260,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Графова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 261,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Nothing',
#   'last_name': 'Personal'},
#  {'id': 262,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 263,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 264,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Пугачёва',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 265,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Истомин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 266,
#   'sex': 2,
#   'first_name': 'Роман',
#   'last_name': 'Захаров',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 267,
#   'sex': 1,
#   'first_name': 'Наталья',
#   'last_name': 'Бердникова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 268,
#   'sex': 2,
#   'first_name': 'Леонид',
#   'last_name': 'Ананьев',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 269,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Миненок',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 270,
#   'sex': 1,
#   'first_name': 'Ирина',
#   'last_name': 'Рыбакова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 271,
#   'sex': 2,
#   'first_name': 'Александр',
#   'last_name': 'Селиванов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 272,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Моржов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 273,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Самойлов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 274,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Тюрина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 275,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Михайлова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 276,
#   'sex': 1,
#   'first_name': 'Катарина',
#   'last_name': 'Коровникова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 277,
#   'sex': 2,
#   'first_name': 'Александр',
#   'last_name': 'Кузнецов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 278,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Грей',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 279,
#   'sex': 1,
#   'first_name': 'Катя',
#   'last_name': 'Розенберг',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 280,
#   'sex': 1,
#   'first_name': 'Вера',
#   'last_name': 'Семенова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 281,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Иванова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 282,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Цимберг',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 283,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Андриенко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 284,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Александр',
#   'last_name': 'Кузнецов'},
#  {'id': 285,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Столовицкая',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 286,
#   'sex': 1,
#   'first_name': 'Маргарита',
#   'last_name': 'Дмитриева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 287,
#   'sex': 2,
#   'first_name': 'Иван',
#   'last_name': 'Кондаков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 288,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Покровский',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 289,
#   'sex': 1,
#   'first_name': 'Юлик',
#   'last_name': 'Суртаева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 290,
#   'sex': 2,
#   'first_name': 'Аркадий',
#   'last_name': 'Гуманюк',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 291,
#   'sex': 2,
#   'first_name': 'Виктор',
#   'last_name': 'Танчак',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 292,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Чупира',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 293,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Жеребкова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 294,
#   'sex': 1,
#   'first_name': 'Татьяна',
#   'last_name': 'Учагина-Василенок',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 295,
#   'sex': 1,
#   'first_name': 'Olga',
#   'last_name': 'Sergeecheva',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 296,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Вязьменская',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 297,
#   'sex': 2,
#   'first_name': 'Владимир',
#   'last_name': 'Сюткин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 298,
#   'sex': 2,
#   'first_name': 'Евгений',
#   'last_name': 'Скоробогатько',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 299,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Вишневская',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 300,
#   'sex': 2,
#   'first_name': 'Юрий',
#   'last_name': 'Новичков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 301,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 302,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Биргер',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 303,
#   'sex': 1,
#   'first_name': 'Оксана',
#   'last_name': 'Ласкателева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 304,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Малашевская',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 305,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Логачев',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 306,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 307,
#   'sex': 1,
#   'first_name': 'Стаська',
#   'last_name': 'Титова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 308,
#   'sex': 2,
#   'first_name': 'Владимир',
#   'last_name': 'Степанов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 309,
#   'sex': 2,
#   'first_name': 'Ilya',
#   'last_name': 'Krivonogov',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 310,
#   'sex': 2,
#   'first_name': 'Константин',
#   'last_name': 'Иванов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 311,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 312,
#   'sex': 2,
#   'first_name': 'Кузьма',
#   'last_name': 'Кукушкин',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 313,
#   'sex': 2,
#   'first_name': 'Виталий',
#   'last_name': 'Шипов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 314,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Прядченко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 315,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Медведев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 316,
#   'sex': 1,
#   'first_name': 'Дарья',
#   'last_name': 'Лесохина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 317,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 318,
#   'sex': 1,
#   'first_name': 'Надежда',
#   'last_name': 'Сомкина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 319,
#   'sex': 1,
#   'first_name': 'Софья',
#   'last_name': 'Астраханцева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 320,
#   'sex': 1,
#   'first_name': 'Марина',
#   'last_name': 'Цветкова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 321,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Гершон',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 322,
#   'sex': 2,
#   'first_name': 'Евгений',
#   'last_name': 'Соколенко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 323,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Орлов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 324,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Логинова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 325,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Желтов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 326,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Яроцкая',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 327,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 328,
#   'sex': 1,
#   'first_name': 'Аня',
#   'last_name': 'Левина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 329,
#   'sex': 1,
#   'first_name': 'Светлана',
#   'last_name': 'Гончаренко',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 330,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Чернецкий',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 331,
#   'sex': 2,
#   'first_name': 'Эмиль',
#   'last_name': 'Байбагышев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 332,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Дима',
#   'last_name': 'Зеленцов'},
#  {'id': 333,
#   'sex': 2,
#   'first_name': 'Агент Поддержки',
#   'last_name': '',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 334,
#   'sex': 1,
#   'first_name': 'Полина',
#   'last_name': 'Богуш',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 335,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Дмитрий',
#   'last_name': 'Овчиннов'},
#  {'id': 336,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 337,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 338,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'last_name': 'Власов'},
#  {'id': 339,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Виктор',
#   'last_name': 'Вавилов'},
#  {'id': 340,
#   'sex': 1,
#   'first_name': 'Oksana',
#   'last_name': 'Fimina',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 341,
#   'sex': 2,
#   'first_name': 'Shmavon',
#   'last_name': 'Gazanchyan',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 342,
#   'sex': 2,
#   'first_name': 'Dmitry',
#   'last_name': 'Svetloff',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 343,
#   'sex': 2,
#   'first_name': 'Андрюха',
#   'last_name': 'Слободинский',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 344,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Фоминых',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 345,
#   'sex': 1,
#   'first_name': 'Дарья',
#   'last_name': 'Фролова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 346,
#   'sex': 1,
#   'first_name': 'Полина',
#   'last_name': 'Маркина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 347,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Андрей',
#   'last_name': 'Бойко'},
#  {'id': 348,
#   'sex': 1,
#   'deactivated': 'banned',
#   'first_name': 'Галина',
#   'last_name': 'Румянцева'},
#  {'id': 349,
#   'sex': 1,
#   'deactivated': 'banned',
#   'first_name': 'Анастасия',
#   'last_name': 'Силюкова'},
#  {'id': 350,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Павел',
#   'last_name': 'Таразевич'},
#  {'id': 351,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Харламова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 352,
#   'sex': 1,
#   'first_name': 'Виктория',
#   'last_name': 'Казакова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 353,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Овчинникова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 354,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Alexxandra',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 355,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Бацманова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 356,
#   'sex': 1,
#   'first_name': 'Арина',
#   'last_name': 'Ускова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 357,
#   'sex': 1,
#   'first_name': 'Аннет',
#   'last_name': 'Григорович',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 358,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Фейн',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 359,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 360,
#   'sex': 1,
#   'first_name': 'Мила',
#   'last_name': 'Мамонтова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 361,
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Кухта',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 362,
#   'sex': 1,
#   'first_name': 'Елена',
#   'last_name': 'Вилинбахова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 363,
#   'sex': 1,
#   'first_name': 'Юлия',
#   'last_name': 'Кудинова-Ли',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 364,
#   'sex': 2,
#   'first_name': 'Альберт',
#   'last_name': 'Александрович',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 365,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 366,
#   'sex': 2,
#   'first_name': 'Вадим',
#   'last_name': 'Кириков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 367,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Коротков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 368,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 369,
#   'sex': 1,
#   'first_name': 'Марина',
#   'last_name': 'Веселова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 370,
#   'sex': 2,
#   'first_name': 'Антон',
#   'last_name': 'Пертусян',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 371,
#   'sex': 1,
#   'first_name': 'Виктория',
#   'last_name': 'Семченкова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 372,
#   'sex': 1,
#   'first_name': 'Маша',
#   'last_name': 'Кильдиярова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 373,
#   'sex': 1,
#   'first_name': 'Светлана',
#   'last_name': 'Порошина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 374,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Волошин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 375,
#   'sex': 2,
#   'first_name': 'Кирилл',
#   'last_name': 'Назаренко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 376,
#   'sex': 2,
#   'first_name': 'Евгений',
#   'last_name': 'Козобродов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 377,
#   'sex': 1,
#   'first_name': 'Надежда',
#   'last_name': 'Маркитантова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 378,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Белая',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 379,
#   'sex': 1,
#   'first_name': 'Татьяна',
#   'last_name': 'Константинова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 380,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 381,
#   'sex': 2,
#   'first_name': 'Манас',
#   'last_name': 'Сираканян',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 382,
#   'sex': 2,
#   'first_name': 'Роман',
#   'last_name': 'Шульман',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 383,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 384,
#   'sex': 2,
#   'first_name': 'Петер',
#   'last_name': 'Славов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 385,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Богданов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 386,
#   'sex': 1,
#   'first_name': 'Надежда',
#   'last_name': 'Супрычева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 387,
#   'sex': 1,
#   'first_name': 'Наталья',
#   'last_name': 'Белая',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 388,
#   'sex': 2,
#   'first_name': 'Валентин',
#   'last_name': 'Бурцев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 389,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Кочнев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 390,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 391,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 392,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 393,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 394,
#   'sex': 1,
#   'first_name': 'Vlasta',
#   'last_name': 'Solovyeva',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 395,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Титов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 396,
#   'sex': 1,
#   'first_name': 'Olga',
#   'last_name': 'Dashkevich',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 397,
#   'sex': 1,
#   'first_name': 'Marina',
#   'last_name': 'Slo',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 398,
#   'sex': 2,
#   'first_name': 'Денис',
#   'last_name': 'Щукин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 399,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 400,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Давыденко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 401,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Поляк',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 402,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Королев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 403,
#   'sex': 1,
#   'first_name': 'Вера',
#   'last_name': 'Веткина',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 404,
#   'sex': 2,
#   'first_name': 'Эдуард',
#   'last_name': 'Николаев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 405,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 406,
#   'sex': 1,
#   'first_name': 'Ольга',
#   'last_name': 'Шарко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 407,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Железнов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 408,
#   'sex': 1,
#   'first_name': 'Ирина',
#   'last_name': 'Белова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 409,
#   'sex': 1,
#   'first_name': 'Виктория',
#   'last_name': 'Якунчикова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 410,
#   'sex': 1,
#   'first_name': 'Alexander',
#   'last_name': 'Obl',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 411,
#   'sex': 1,
#   'first_name': 'Нина',
#   'last_name': 'Отмас',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 412,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 413,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 414,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 415,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 416,
#   'sex': 1,
#   'first_name': 'Евгения',
#   'last_name': 'Жаржавская',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 417,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 418,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 419,
#   'sex': 2,
#   'first_name': 'Ярослав',
#   'last_name': 'Воронцов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 420,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Телегина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 421,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Щёголева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 422,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Соколов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 423,
#   'sex': 2,
#   'first_name': 'Тимур',
#   'last_name': 'Кармов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 424,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 425,
#   'sex': 1,
#   'deactivated': 'banned',
#   'first_name': 'Анна',
#   'last_name': 'Войтенко'},
#  {'id': 426,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Коновалова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 427,
#   'sex': 1,
#   'first_name': 'Алена',
#   'last_name': 'Матвейчук',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 428,
#   'sex': 2,
#   'first_name': 'Александр',
#   'last_name': 'Кирпичников',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 429,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Зубков',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 430,
#   'sex': 2,
#   'first_name': 'Piotr',
#   'last_name': 'Gr',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 431,
#   'sex': 1,
#   'first_name': 'Мария',
#   'last_name': 'Ажинова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 432,
#   'sex': 1,
#   'first_name': 'Ný',
#   'last_name': 'Lero',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 433,
#   'sex': 1,
#   'first_name': 'Анастасия',
#   'last_name': 'Мальмрус',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 434,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Золотонос',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 435,
#   'sex': 2,
#   'first_name': 'Кирилл',
#   'last_name': 'Субботин',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 436,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Сергей',
#   'last_name': 'Дюжев'},
#  {'id': 437,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 438,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Шипилов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 439,
#   'sex': 2,
#   'first_name': 'Тимофей',
#   'last_name': 'Стороженко',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 440,
#   'sex': 1,
#   'first_name': 'Anastasia',
#   'last_name': 'Balashova',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 441,
#   'sex': 1,
#   'first_name': 'Евгения',
#   'last_name': 'Нигматуллина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 442,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 443,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Юрецкий',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 444,
#   'sex': 1,
#   'deactivated': 'banned',
#   'first_name': 'Алиса',
#   'last_name': 'Иванова'},
#  {'id': 445,
#   'sex': 2,
#   'first_name': 'Филипп',
#   'last_name': 'Рамбов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 446,
#   'sex': 2,
#   'first_name': 'Владимир',
#   'last_name': 'Богданов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 447,
#   'sex': 1,
#   'first_name': 'Marianna',
#   'last_name': 'Demenkova',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 448,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Никита',
#   'last_name': 'Аникеев'},
#  {'id': 449,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 450,
#   'sex': 1,
#   'first_name': 'Марина',
#   'last_name': 'Требина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 451,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'Ксения',
#   'last_name': 'Грюнвальд'},
#  {'id': 452,
#   'sex': 2,
#   'first_name': 'Олег',
#   'last_name': 'Желтянников',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 453,
#   'sex': 1,
#   'first_name': 'Ярославна',
#   'last_name': 'Гаген-Торн',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 454,
#   'sex': 2,
#   'first_name': 'Андрей',
#   'last_name': 'Гук',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 455,
#   'sex': 2,
#   'first_name': 'Евгений',
#   'last_name': 'Шехтер',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 456,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 457,
#   'sex': 2,
#   'first_name': 'Владимир',
#   'last_name': 'Баранов',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 458,
#   'sex': 2,
#   'first_name': 'Сергей',
#   'last_name': 'Нагапетян',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 459,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 460,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Ilya',
#   'last_name': 'Dneprovsky'},
#  {'id': 461,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 462,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 463,
#   'sex': 1,
#   'first_name': 'Людмила',
#   'last_name': 'Захарова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 464,
#   'sex': 2,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 465,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 466,
#   'sex': 1,
#   'first_name': 'Anastasia',
#   'last_name': 'Mikhaylova',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 467,
#   'sex': 2,
#   'first_name': 'Игорь',
#   'last_name': 'Перекопский',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 468,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Паша',
#   'last_name': 'Кипелов'},
#  {'id': 469,
#   'sex': 1,
#   'first_name': 'Екатерина',
#   'last_name': 'Пушкина',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 470,
#   'sex': 2,
#   'first_name': 'Антон',
#   'last_name': 'Зайцев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 471,
#   'sex': 2,
#   'first_name': 'Дмитрий',
#   'last_name': 'Никончук',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 472,
#   'sex': 1,
#   'first_name': 'Евгения',
#   'last_name': 'Захарова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 473,
#   'sex': 1,
#   'first_name': 'Алёна',
#   'last_name': 'Тайлер',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 474,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 475,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 476,
#   'sex': 1,
#   'first_name': 'Лена',
#   'last_name': 'Самуйлова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 477,
#   'sex': 2,
#   'deactivated': 'banned',
#   'first_name': 'Алексей',
#   'last_name': 'Комаров'},
#  {'id': 478,
#   'sex': 2,
#   'first_name': 'Кирилл',
#   'last_name': 'Мошков',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 479,
#   'sex': 1,
#   'first_name': 'Виктория',
#   'last_name': 'Стацевич',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 480,
#   'sex': 2,
#   'first_name': 'Yarik',
#   'last_name': 'Markov',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 481,
#   'sex': 1,
#   'first_name': 'Софья',
#   'last_name': 'Чебанова',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 482,
#   'sex': 1,
#   'first_name': 'Юлия',
#   'last_name': 'Васильева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 483,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 484,
#   'sex': 1,
#   'first_name': 'Юлия',
#   'last_name': 'Нураева',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 485,
#   'sex': 1,
#   'deactivated': 'banned',
#   'first_name': 'Дарья',
#   'last_name': 'Павлова'},
#  {'id': 486,
#   'sex': 1,
#   'first_name': 'Наталия',
#   'last_name': 'Юрасова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 487,
#   'sex': 1,
#   'first_name': 'Светлана',
#   'last_name': 'Каткова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 488,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Леонидович',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 489,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Родионова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 490,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'Елена',
#   'last_name': 'Ящике'},
#  {'id': 491,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 492,
#   'sex': 2,
#   'first_name': 'Кирилл',
#   'last_name': 'Ширяев',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 493,
#   'sex': 1,
#   'first_name': 'Дарья',
#   'last_name': 'Монихарт',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 494,
#   'sex': 1,
#   'first_name': 'Анна',
#   'last_name': 'Бабурова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 495,
#   'sex': 2,
#   'first_name': 'Михаил',
#   'last_name': 'Кадобнов',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 496,
#   'sex': 2,
#   'first_name': 'Григорий',
#   'last_name': 'Малыгин',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 497,
#   'sex': 1,
#   'first_name': 'Светлана',
#   'last_name': 'Лапина',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 498,
#   'sex': 1,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 499,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 500,
#   'sex': 2,
#   'first_name': 'Анонимный пользователь',
#   'last_name': '',
#   'can_access_closed': True,
#   'is_closed': False}]

# %%
users_m = 0
users_w = 0
for x in users500:
    if x['sex'] == 2:
        users_m +=1
    elif x['sex'] == 1:
        users_w +=1
    else:
        continue
round(users_w/(users_m+users_w),3)
# Out:
# 0.485

# %% [markdown]
# #### <center>СБОР ИНФОРМАЦИИ ИЗ ГРУПП

# %% [markdown]
# В одном из предыдущих юнитов в качестве примера мы собрали информацию о небольшом количестве пользователей. Теперь перейдём к более реальной задаче — сбору данных о пользователях группы ВКонтакте.

# %% [markdown]
# *Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:*
#
# * не учитываются все особенности вашего проекта;
# * используется фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# * не всегда бесплатны и вряд ли позволят работать с большими объёмами данных.

# %% [markdown]
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# * ограничение на количество вызовов в единицу времени;
# * ограничение на количество выгружаемых строк за один запрос.

# %% [markdown]
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.

# %% [markdown]
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.

# %% [markdown]
# Обратимся к документации https://vk.com/dev/groups, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers https://vk.com/dev/groups.getMembers.

# %% [markdown]
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
#import requests # Импортируем модуль requests
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13078937, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7408, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9352, 9399, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12859, 12892, 12922, 12932, 12952, 12957, 12982, 13008, 13063, 13080 ...

# %% [markdown]
# По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на него поближе:

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

# %%
#import requests # Импортируем модуль requests
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640]

# %% [markdown]
# Сравним списки, полученные двумя способами:

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].

# %% [markdown]
# #### <center>ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ

# %% [markdown]
# *→ В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.*

# %% [markdown]
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
#import requests # Импортируем модуль requests
import time # Импортируем модуль time
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# #### <center>ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ

# %% [markdown]
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 100 сообщений в новостной ленте.

# %% [markdown]
# *Примечание: обратите внимание, что т.к. сообщения в новостной ленте непрерывно обновляются, то ваш результат выполнения кода ниже будет отличаться от нашего варианта.*

# %% [markdown]
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
#import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
#token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 570,
#               'items': [{'attachments': [],
#                          'comments': {'can_post': 1,
#                                       'count': 300,
#                                       'groups_can_post': True},
#                          'copy_history': [{'attachments': [{'photo': {'access_key': '3a7a6d1f7a4cbaf7c5',
#                                                                       'album_id': -7,
#                                                                       'date': 1672506337,
#                                                                       'id': 457240174,
#                                                                       'owner_id': 92933,
#                                                                       'post_id': 582,
#                                                                       'sizes': [{'height': 130,
#                                                                                  'type': 'm',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=130x130&quality=96&sign=f78d529693d56329fa208ba57b471e77&c_uniq_tag=ASNzeXj9PQVONyfOi9482YzJHesTpYgrxaDlX0RybLw&type=album',
#                                                                                  'width': 130},
#                                                                                 {'height': 130,
#                                                                                  'type': 'o',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=130x130&quality=96&sign=f78d529693d56329fa208ba57b471e77&c_uniq_tag=ASNzeXj9PQVONyfOi9482YzJHesTpYgrxaDlX0RybLw&type=album',
#                                                                                  'width': 130},
#                                                                                 {'height': 200,
#                                                                                  'type': 'p',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=200x200&quality=96&sign=91632907f4d312cc473819be001dc208&c_uniq_tag=CNoGi-sV5Hy0Q-HbtqjPGLU_PMGuKrf50DYxFk3DSVg&type=album',
#                                                                                  'width': 200},
#                                                                                 {'height': 320,
#                                                                                  'type': 'q',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=320x320&quality=96&sign=e9f9dc6124d8c9c9afc6c592e2e79bc7&c_uniq_tag=DbA9vZNecMcjugpIyIk0TWw88F8NsuzMQkQFRIXKpJs&type=album',
#                                                                                  'width': 320},
#                                                                                 {'height': 510,
#                                                                                  'type': 'r',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=510x510&quality=96&sign=354c8846b0a1b2e57b26caf17deceeb5&c_uniq_tag=RXI6v_BvNAvFve4YktC6QfTCDDDNrIxCDbuI_-uxtsw&type=album',
#                                                                                  'width': 510},
#                                                                                 {'height': 75,
#                                                                                  'type': 's',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=75x75&quality=96&sign=9e706c891261f589a9433538baaabda8&c_uniq_tag=x7sT5CwYy84nMwFWIj_qk9O6qiauZiRq_CyiyTTyUIw&type=album',
#                                                                                  'width': 75},
#                                                                                 {'height': 2000,
#                                                                                  'type': 'w',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=2000x2000&quality=96&sign=bf760dc9260e2c31c69faabd9768a437&c_uniq_tag=s4uvDu7EV6rLNlastLG-wEv-1vAyKsUHQMtXyRZSjO8&type=album',
#                                                                                  'width': 2000},
#                                                                                 {'height': 604,
#                                                                                  'type': 'x',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=604x604&quality=96&sign=51e3793d2dc188deced8aa0e67714640&c_uniq_tag=UPqFapJLfTMWiiGsDMxCVwzFVE1XCnusqsgfWYdpmIc&type=album',
#                                                                                  'width': 604},
#                                                                                 {'height': 807,
#                                                                                  'type': 'y',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=807x807&quality=96&sign=7447df0f6bed8830075bf3029d2877d7&c_uniq_tag=U8HZsdSvY9yhAf49ZGr9FBbKqz3JvTLrzwEu4nexFyY&type=album',
#                                                                                  'width': 807},
#                                                                                 {'height': 1280,
#                                                                                  'type': 'z',
#                                                                                  'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=1280x1280&quality=96&sign=2461a096b133253d2b177316d776574b&c_uniq_tag=j_QfhccYgHlCr40P3LK3WXLKFw1ScvBJKbaJK5hvZTI&type=album',
#                                                                                  'width': 1280}],
#                                                                       'text': ''},
#                                                             'type': 'photo'}],
#                                            'date': 1672506610,
#                                            'from_id': 92933,
#                                            'id': 582,
#                                            'owner_id': 92933,
#                                            'post_source': {'type': 'vk'},
#                                            'post_type': 'post',
#                                            'text': '2022-й без преувеличения '
#                                                    'можно назвать рекордным '
#                                                    'для нашей Команды. В '
#                                                    'течение года мы '
#                                                    'рассказывали о наших '
#                                                    'результатах, запусках и '
#                                                    'ключевых событиях — мы '
#                                                    'представили свыше 230 '
#                                                    'продуктовых и '
#                                                    'технологических '
#                                                    'обновлений. Улучшения '
#                                                    'коснулись всех наших '
#                                                    'продуктов — и это '
#                                                    'позволило нам добиться '
#                                                    'невероятных успехов. \n'
#                                                    '\n'
#                                                    'Ежемесячная аудитория '
#                                                    'ВКонтакте впервые '
#                                                    'превысила 100 миллионов '
#                                                    'пользователей, мы стали '
#                                                    'первой соцсетью в России '
#                                                    'по среднему времени '
#                                                    'посещения, количеству '
#                                                    'публикаций и авторов, '
#                                                    'ежедневные просмотры видео '
#                                                    'на платформе '
#                                                    'видеотехнологий VK за 11 '
#                                                    'месяцев выросли на 49%, до '
#                                                    '2,75 млрд, VK Звонки '
#                                                    'названы лучшим решением '
#                                                    'для видеоконференций на '
#                                                    'iOS и Android, VK '
#                                                    'Мессенджер — самым '
#                                                    'популярным мессенджером у '
#                                                    'школьников, число '
#                                                    'приложений на платформе VK '
#                                                    'Mini Apps достигло отметки '
#                                                    '63 тысячи, а VK Клипы '
#                                                    'стали лидером среди '
#                                                    'российских сервисов '
#                                                    'коротких роликов и '
#                                                    'установили рекорд в 1 млрд '
#                                                    'ежедневных просмотров.\n'
#                                                    '\n'
#                                                    'О результатах мы '
#                                                    'традиционно рассказывали '
#                                                    'на протяжении всего '
#                                                    'декабря в специальном '
#                                                    'разделе ВКонтакте: '
#                                                    'vk.com/2022 — здесь '
#                                                    'сможете узнать больше про '
#                                                    'наши продуктовые итоги, '
#                                                    'благотворительные '
#                                                    'инициативы и '
#                                                    'технологические '
#                                                    'обновления, среди которых '
#                                                    '— новая рекомендательная '
#                                                    'система VK Клипов, '
#                                                    'совместный просмотр '
#                                                    'медиаконтента во время '
#                                                    'видеоконференций, '
#                                                    'уникальные цифровые '
#                                                    'аватары vmoji, запуск VK '
#                                                    'NFT и многое другое.\n'
#                                                    '\n'
#                                                    'За каждым запуском, '
#                                                    'обновлением и '
#                                                    'технологическим прорывом '
#                                                    'стоит большая Команда, '
#                                                    'которая каждый день '
#                                                    'работает над созданием '
#                                                    'простых и удобных '
#                                                    'инструментов коммуникации. '
#                                                    'Спасибо Команде ВКонтакте '
#                                                    '— талантливейшим людям, '
#                                                    'которые вдохновляют и '
#                                                    'восхищают. Верю, что в '
#                                                    'следующем году нас ждёт '
#                                                    'ещё больше крутых '
#                                                    'обновлений, технологичных '
#                                                    'инструментов и новых '
#                                                    'побед! \n'
#                                                    '\n'
#                                                    'Мы будем рады создавать и '
#                                                    'развивать наши сервисы — '
#                                                    'чтобы помогать вам '
#                                                    'общаться с друзьями, быть '
#                                                    'на связи с семьёй, '
#                                                    'находить единомышленников '
#                                                    'и новые знакомства, '
#                                                    'эффективно развивать свой '
#                                                    'бизнес, учиться и '
#                                                    'саморазвиваться, отдыхать '
#                                                    'и веселиться, продуктивно '
#                                                    'заниматься повседневными '
#                                                    'вопросами, получать новые '
#                                                    'впечатления и делиться ими '
#                                                    'с другими. Пусть в 2023-м '
#                                                    'всегда будет чем '
#                                                    'поделиться! \n'
#                                                    '\n'
#                                                    'С наступающим Новым годом! '
#                                                    'Будем ВКонтакте 💙'}],
#                          'date': 1672506763,
#                          'from_id': -22822305,
#                          'hash': 'gS9QvURcyoUvNo_zHw',
#                          'id': 1374716,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1996,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 479, 'user_reposted': 0},
#                          'text': '',
#                          'views': {'count': 375761}},
#                         {'attachments': [],
#                          'comments': {'can_post': 1,
#                                       'count': 115,
#                                       'groups_can_post': True},
#                          'copy_history': [{'attachments': [{'link': {'caption': 'trends.rbc.ru',
#                                                                      'description': 'Ежемесячно '
#                                                                                     '«ВКонтакте» '
#                                                                                     'пользуется '
#                                                                                     '85% '
#                                                                                     'аудитории '
#                                                                                     'рунета. '
#                                                                                     'О '
#                                                                                     'запуске '
#                                                                                     'новых '
#                                                                                     'продуктов '
#                                                                                     'в '
#                                                                                     '2022 '
#                                                                                     'году, '
#                                                                                     'цифровых '
#                                                                                     'аватарах '
#                                                                                     'и '
#                                                                                     'виртуальных '
#                                                                                     'вселенных, '
#                                                                                     'а '
#                                                                                     'также '
#                                                                                     'о '
#                                                                                     'трендах '
#                                                                                     'развития '
#                                                                                     'соцсетей '
#                                                                                     'рассказала '
#                                                                                     'CEO '
#                                                                                     'платформы '
#                                                                                     'Марина '
#                                                                                     'Краснова',
#                                                                      'photo': {'album_id': -25,
#                                                                                'date': 1672419661,
#                                                                                'id': 457439683,
#                                                                                'owner_id': 2000003296,
#                                                                                'sizes': [{'height': 480,
#                                                                                           'type': 'k',
#                                                                                           'url': 'https://sun6-21.userapi.com/impg/a5iAX4wny_C8OsQTYFdGVFbHVYe930Pfbi3tlw/7lL1qfKCgh0.jpg?size=1074x480&quality=96&sign=919434471995d8dca92206c004651477&c_uniq_tag=nyRn4NzZI3qbBY1YwOtZudk6isfQ9H0DbPNqEx3N9Mk&type=share',
#                                                                                           'width': 1074},
#                                                                                          {'height': 240,
#                                                                                           'type': 'l',
#                                                                                           'url': 'https://sun6-21.userapi.com/impg/a5iAX4wny_C8OsQTYFdGVFbHVYe930Pfbi3tlw/7lL1qfKCgh0.jpg?size=537x240&quality=96&sign=1aaf40f25eaed8184c17efacffec908c&c_uniq_tag=3V2QY8NUhEKEq1FPjMmuH8gf3gTbjq4BaLZ5YrOEGEg&type=share',
#                                                                                           'width': 537},
#                                                                                          {'height': 80,
#                                                                                           'type': 'm',
#                                                                                           'url': 'https://sun6-21.userapi.com/impg/a5iAX4wny_C8OsQTYFdGVFbHVYe930Pfbi3tlw/7lL1qfKCgh0.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=d7429a2a18bfc62ed53543d8bcf5ca4d&c_uniq_tag=1bYeDBBUElqhPGB_WAFhv8RlBIg9By4-7ArVW8H7HV0&type=share',
#                                                                                           'width': 130},
#                                                                                          {'height': 140,
#                                                                                           'type': 'p',
#                                                                                           'url': 'https://sun6-21.userapi.com/impg/a5iAX4wny_C8OsQTYFdGVFbHVYe930Pfbi3tlw/7lL1qfKCgh0.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=5db8a2210a8597e6b8cc65d04d8c8a03&c_uniq_tag=3SbvjQZtKL-qs3t7rAbxGZUnQqLGM7MdcKGr41-fjKM&type=share',
#                                                                                           'width': 260},
#                                                                                          {'height': 35,
#                                                                                           'type': 's',
#                                                                                           'url': 'https://sun6-21.userapi.com/impg/a5iAX4wny_C8OsQTYFdGVFbHVYe930Pfbi3tlw/7lL1qfKCgh0.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=13e9210c4480f2fa19702fa976590178&c_uniq_tag=C8xXQi_t_uaTuT-tjQ1w7MZgunHBcVqPPq9ytPKyKRw&type=share',
#                                                                                           'width': 75},
#                                                                                          {'height': 80,
#                                                                                           'type': 'x',
#                                                                                           'url': 'https://sun6-21.userapi.com/impg/a5iAX4wny_C8OsQTYFdGVFbHVYe930Pfbi3tlw/7lL1qfKCgh0.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=14ac212e15c62f42a5094f691cf93d4e&c_uniq_tag=9ZS1xKmwmq9QyMq0_tdHXpOz68a93_07hKrDaEEEEYE&type=share',
#                                                                                           'width': 150}],
#                                                                                'text': '',
#                                                                                'user_id': 100},
#                                                                      'title': 'Марина '
#                                                                               'Краснова: '
#                                                                               '«Самый '
#                                                                               'ценный '
#                                                                               'ресурс '
#                                                                               'сегодня '
#                                                                               '— '
#                                                                               'время '
#                                                                               'пользователя» '
#                                                                               '| '
#                                                                               'РБК '
#                                                                               'Тренды',
#                                                                      'url': 'http://trends.rbc.ru/trends/industry/cmrm/63ad70ba9a794715c69a0aa2'},
#                                                             'type': 'link'}],
#                                            'date': 1672419651,
#                                            'from_id': 92933,
#                                            'id': 572,
#                                            'owner_id': 92933,
#                                            'post_source': {'platform': 'android',
#                                                            'type': 'api'},
#                                            'post_type': 'post',
#                                            'text': 'Год завершается, а я '
#                                                    'поделилась ключевыми '
#                                                    'достижениями ВКонтакте за '
#                                                    '2022 год в интервью для '
#                                                    '«РБК Тренды». \n'
#                                                    '\n'
#                                                    'Озвучили актуальные цифры '
#                                                    'и наши фантастические '
#                                                    'рекорды, поговорили про '
#                                                    'запуски и новые продукты, '
#                                                    'обсудили лидерство '
#                                                    'ВКонтакте, рост Команды, '
#                                                    'тренды развития соцсетей, '
#                                                    'цифровые аватары и '
#                                                    'виртуальные вселенные, а '
#                                                    'также грандиозные планы на '
#                                                    '2023-й и многое другое: '
#                                                    'trends.rbc.ru/trends/industry/cmrm/63ad70ba9a794715c69a0aa2\n'
#                                                    '\n'
#                                                    'ВКонтакте сегодня — это: \n'
#                                                    ' • 85% аудитории рунета '
#                                                    'каждый месяц\n'
#                                                    ' • 100 миллионов активных '
#                                                    'пользователей в месяц\n'
#                                                    ' • 6,3 млрд единиц '
#                                                    'контента, созданных '
#                                                    'пользователями в 2022 '
#                                                    'году\n'
#                                                    ' • 8 млн уникальных '
#                                                    'цифровых аватаров vmoji\n'
#                                                    'А ещё 2,75 млрд просмотров '
#                                                    'видео в сутки на платформе '
#                                                    'видеотехнологий VK, 20 млн '
#                                                    'пользователей VK Звонков, '
#                                                    '750 млн суточных '
#                                                    'просмотров в VK Клипах и '
#                                                    'многое другое. \n'
#                                                    '\n'
#                                                    'В этом году мы представили '
#                                                    'новые сервисы и уникальные '
#                                                    'технологии — к примеру, '
#                                                    'совместный просмотр '
#                                                    'видеоконтента в VK '
#                                                    'Звонках, платформу VK NFT, '
#                                                    'ленту «Актуальное», '
#                                                    'отдельные приложения VK '
#                                                    'Звонков, VK Мессенджера и '
#                                                    'VK Клипов, новый дизайн '
#                                                    'ВКонтакте, приложение для '
#                                                    'Apple Watch, SDK VK Видео '
#                                                    'и VK Звонков для сторонних '
#                                                    'разработчиков. \n'
#                                                    'Больше цифр и интересных '
#                                                    'фактов — в материале.'}],
#                          'date': 1672419951,
#                          'from_id': -22822305,
#                          'hash': 'YjkXOBPbVkDrG8e1cw',
#                          'id': 1374404,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 751,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 268, 'user_reposted': 0},
#                          'text': 'CEO ВКонтакте Марина Краснова делится '
#                                  'итогами года и планами на 2023-й.',
#                          'views': {'count': 271277}},
#                         {'attachments': [{'photo': {'access_key': 'a0a3a804d2717b1725',
#                                                     'album_id': -7,
#                                                     'date': 1672319387,
#                                                     'id': 457338414,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1372808,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=75x75&quality=95&sign=047852b79bd1b470336c91ec752b7686&c_uniq_tag=OKwqP4u_Ypk7O97AMXp3MQJqkIZFxV1NJQ4-mVlcSl8&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=130x130&quality=95&sign=254dcf08cf9246d898207a29a79b0163&c_uniq_tag=Yyt20aBJmIv5jss5_KH_eEDyvdCarAIU4ohXONsD6w8&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=604x604&quality=95&sign=acc7aeb72efc516a642684349d2e59bf&c_uniq_tag=IEl1afUraQZ1wPfl5h_Ipn5hg4qx86oALM0GjH08CFg&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=807x807&quality=95&sign=f33d72e7b5c7fff9d1deecb8324c8fdc&c_uniq_tag=JC2U3ywavUaI_gwvleiKWh7c9NpyuNZyASnL6V7IkZo&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=1280x1280&quality=95&sign=9e1f077fe72da27dd26a22a850e6bb01&c_uniq_tag=CrfQqzr20E0V3jZ05eE6nRwI7fVOpR8AeI5H2eqmN9k&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=1500x1500&quality=95&sign=b697be63c9fb5ab09a358186eeba8d4f&c_uniq_tag=yHsXz2gE90uzTI9oYs5R_tZVz1cb8EA75zr0bxutUa8&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=130x130&quality=95&sign=254dcf08cf9246d898207a29a79b0163&c_uniq_tag=Yyt20aBJmIv5jss5_KH_eEDyvdCarAIU4ohXONsD6w8&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=200x200&quality=95&sign=31f351f35fdada327f98744af21c4e5d&c_uniq_tag=KoZHRG_kia1MV18B9GCFyu_Nxo45acDcYQNehv4AV3g&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=320x320&quality=95&sign=f0605a52bcc5834608f23ea65f72a8bc&c_uniq_tag=gBe4sSq847RV6TprcUFnUr_l75ee8FBhFrTNUgModY0&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-21.userapi.com/impg/Tqi2cZket0BSIkPw3LOpXnCXoOXPtvmZVcQxEw/p_6djD2h184.jpg?size=510x510&quality=95&sign=4e8ac9a72524af26468bd2d0f9e7113c&c_uniq_tag=y8u67UKwVrJspqY8qtzOQ4EAqBKg4F-0jFG2CQ6Sc8I&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 175,
#                                       'groups_can_post': True},
#                          'date': 1672328610,
#                          'from_id': -22822305,
#                          'hash': 'DjxJ-8IPUBLkyIjh1g',
#                          'id': 1372808,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1054,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 299, 'user_reposted': 0},
#                          'text': 'Что обсуждали, смотрели и слушали ВКонтакте '
#                                  'в 2022 году? Главные игры, треки, мемы, '
#                                  'фильмы, продуктовые и технологические '
#                                  'новинки — собрали итоги года в специальном '
#                                  'разделе: vk.com/2022.',
#                          'views': {'count': 271532}},
#                         {'attachments': [{'photo': {'access_key': 'f8d80972503977bdac',
#                                                     'album_id': -7,
#                                                     'date': 1672298124,
#                                                     'id': 457338383,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1372195,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=75x75&quality=95&sign=d9505c695495e756aa6aeb1b6fab3278&c_uniq_tag=R7Ay1YCSVJh2hTWTEvbHgsHlLXf_aCtuiEdrBjlKb00&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=130x130&quality=95&sign=09dda49f02a51084e5c19e2c4cbbff2c&c_uniq_tag=mKdoAFaZcXKMusu7rK6DTqsbJrtWv90Ii365_dKTcds&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=604x604&quality=95&sign=27cad08ba657ec58baafaea42cebc8b1&c_uniq_tag=PzyiggASD0fTFnmjWF3V9aHDDoCGHn5XjkNxJBDBREo&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=807x807&quality=95&sign=fdc4539af8bf2c6ceb8da5fe90b0c046&c_uniq_tag=hT9JY5LK5oeDIgieg8NXjfphPKERWjabZ3tK8NhGHmI&type=album',
#                                                                'width': 807},
#                                                               {'height': 1200,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=1200x1200&quality=95&sign=cf3c4c90618ecb1e4f0ada83a68d2db8&c_uniq_tag=SEUEEi2IeFfDqOVBr40OmjpjM2gm5UDxR8AmpCRvGaQ&type=album',
#                                                                'width': 1200},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=130x130&quality=95&sign=09dda49f02a51084e5c19e2c4cbbff2c&c_uniq_tag=mKdoAFaZcXKMusu7rK6DTqsbJrtWv90Ii365_dKTcds&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=200x200&quality=95&sign=1b819ac0c1fa8f5a708f0cf99d1a0e69&c_uniq_tag=E9ACL_r3J4Uk90_7_klAVPANzbvlKVExJ1vKjXPfBrw&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=320x320&quality=95&sign=c1166452c841b226f4f52f2f62ffef41&c_uniq_tag=GbuOX5qcvQUVBSku19LgFRaJNk40KwwE2BqNmZynxVo&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-23.userapi.com/impg/CrCXTkhuzaFepqMdwS1svBb1TG4jY4JFhI869w/vPX2ICn3Jdk.jpg?size=510x510&quality=95&sign=806ee5244ec1cab5df6a75dba3048909&c_uniq_tag=7xREvP-5pOCVlWy_0jvQD_4UKwgT8-VlxUhWNUXPWGY&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 117,
#                                       'groups_can_post': True},
#                          'date': 1672300776,
#                          'from_id': -22822305,
#                          'hash': 'W4edzk5bxszNXayddA',
#                          'id': 1372195,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1266,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 294, 'user_reposted': 0},
#                          'text': 'ВКонтакте есть добрая новогодняя традиция — '
#                                  'дарить друг другу благотворительный подарок. '
#                                  'Отправьте друзьям символ 2023 года — чёрного '
#                                  'кролика по имени Бантик. Вырученные средства '
#                                  'пойдут в фонд борьбы с инсультом '
#                                  '[https://vk.com/orbifond|ОРБИ], центр '
#                                  'реабилитации животных '
#                                  '[https://vk.com/spasibozavernost|«Верность»] '
#                                  'и благотворительное движение '
#                                  '[https://vk.com/club_iskorka|«Искорка '
#                                  'Фонд»].\n'
#                                  '\n'
#                                  'Стоимость подарка — 5 голосов.\n'
#                                  'Отправлять его можно до 15 января: '
#                                  'vk.com/gifts?act=send.',
#                          'views': {'count': 275835}},
#                         {'attachments': [{'photo': {'access_key': '8a868d22a931dd7d97',
#                                                     'album_id': -7,
#                                                     'date': 1672144338,
#                                                     'id': 457338265,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1371807,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-20.userapi.com/impg/YJMk5b2IshXtYGEfoOP1yT4QkyCq7WX1DNDzdA/fKg0Wf52KXQ.jpg?size=75x75&quality=95&sign=62843a30710d8342117c0b988cb45534&c_uniq_tag=7OB8fGpLij79ZsEShADd2tnQfxJR_Cwcdk59ybzRJgQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-20.userapi.com/impg/YJMk5b2IshXtYGEfoOP1yT4QkyCq7WX1DNDzdA/fKg0Wf52KXQ.jpg?size=130x130&quality=95&sign=e1cf56f5e68427a5f044291322492c1f&c_uniq_tag=pZlmSrl7zZYzPhD-WJci6o-9ISYbI_R2GFVfWfcEWNc&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-20.userapi.com/impg/YJMk5b2IshXtYGEfoOP1yT4QkyCq7WX1DNDzdA/fKg0Wf52KXQ.jpg?size=604x604&quality=95&sign=1d2d60b7176737fb73a503ad35b1d851&c_uniq_tag=E0ENE06QtyV3sDhgcAUDXBbmZOojuD9VcM1Bt9ITclo&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-20.userapi.com/impg/YJMk5b2IshXtYGEfoOP1yT4QkyCq7WX1DNDzdA/fKg0Wf52KXQ.jpg?size=807x807&quality=95&sign=cf2c7fcf79c810c846e8e9e21a37dc0d&c_uniq_tag=xY7f-uEK_RDMm17o0wcVeJoVq9mucDRkiJMFwG8Tozw&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-20.userapi.com/impg/YJMk5b2IshXtYGEfoOP1yT4QkyCq7WX1DNDzdA/fKg0Wf52KXQ.jpg?size=1280x1280&quality=95&sign=4f4dd066f169ef5bb011241faa844f78&c_uniq_tag=r4gduFHbAzv-acjKHpoAHtDWTAjAc6_TdsaTBUV57-g&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-20.userapi.com/impg/YJMk5b2IshXtYGEfoOP1yT4QkyCq7WX1DNDzdA/fKg0Wf52KXQ.jpg?size=1500x1500&quality=95&sign=0c7d8e36a4fbd577d59f30cbe07f9889&c_uniq_tag=x74o3A-gHIL778WQcBvSnB-gxtnfAvEjX-OJkshkLUA&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
# ...
#                                  'возможностях ВКонтакте в подробностях.',
#                          'views': {'count': 654960}},
#                         {'attachments': [{'link': {'caption': 'm.vk.com',
#                                                    'description': 'Article',
#                                                    'photo': {'album_id': -66,
#                                                              'date': 1647436484,
#                                                              'id': 457329479,
#                                                              'owner_id': -22822305,
#                                                              'sizes': [{'height': 73,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=130x73&quality=96&sign=87d0025caf7acad1db47d92121ed908a&c_uniq_tag=20FlrfldewluEZm3qcKf5mmRc4HxUHmQwHJjfSWz-tA&type=album',
#                                                                         'width': 130},
#                                                                        {'height': 87,
#                                                                         'type': 'o',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=130x87&quality=96&crop=102,0,1076,720&sign=57ebe8c0fce7ba84735d98d968171831&c_uniq_tag=d2TfXIIlH48P7bU0kjJUPQMZsra_e-swDmnnJjwi2JU&type=album',
#                                                                         'width': 130},
#                                                                        {'height': 133,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=200x133&quality=96&crop=98,0,1083,720&sign=6cc1be5c97bea34e3e58dad7ec9cba82&c_uniq_tag=hJK8Pm3iYbXgsFXlKwJW-WMMAO7zGW_rOp6J4A8ySYM&type=album',
#                                                                         'width': 200},
#                                                                        {'height': 213,
#                                                                         'type': 'q',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=320x213&quality=96&crop=99,0,1082,720&sign=9d2ebba707c543c874df04a6d157db29&c_uniq_tag=Py3--NDXQZULhG1fx26bF7kNFS_pIkAZCrHMvgRsjRc&type=album',
#                                                                         'width': 320},
#                                                                        {'height': 340,
#                                                                         'type': 'r',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=510x340&quality=96&crop=100,0,1080,720&sign=7218930d1210b1e91005af72a7350465&c_uniq_tag=rN_te1VhggDfmgbfcC-klCm2Q3ayICnHCx-MkEurLtU&type=album',
#                                                                         'width': 510},
#                                                                        {'height': 42,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=75x42&quality=96&sign=87881e15efb53519be7f69b3481d8fab&c_uniq_tag=dxYrGRzQCdQph6xWPX9wnuOFgf3NzYcMXizisPg_QIc&type=album',
#                                                                         'width': 75},
#                                                                        {'height': 340,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=604x340&quality=96&sign=043894fec6959b4b9f35df9ddb46c2b2&c_uniq_tag=I65judbNpM0TVbWFRsxXFTGGt1RKvyxbRNJBeiX5Sv8&type=album',
#                                                                         'width': 604},
#                                                                        {'height': 454,
#                                                                         'type': 'y',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=807x454&quality=96&sign=c40178a3b2c88025d0df52038b4c6384&c_uniq_tag=cCYdtbmADOkrSGpYHk6W0AokPWbylDdSL9uAgfdM7I4&type=album',
#                                                                         'width': 807},
#                                                                        {'height': 720,
#                                                                         'type': 'z',
#                                                                         'url': 'https://sun6-23.userapi.com/impg/RaJBfDLRO3LB1xVN53ad5YyVe_I-2lLh6UP4pw/QXU2KPTC6Sk.jpg?size=1280x720&quality=96&sign=3bac5fc1b065086d3e50c6f20f87cc38&c_uniq_tag=B5VjGmzTTb8LE6qv5UnhwtZw1nHBtq1NqMDJjSYN59s&type=album',
#                                                                         'width': 1280}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'title': 'Как настроить '
#                                                             'приватность и '
#                                                             'усилить защиту '
#                                                             'профиля: три '
#                                                             'совета',
#                                                    'url': 'https://m.vk.com/@vk-security-privacy'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 2022,
#                                       'groups_can_post': True},
#                          'date': 1647437245,
#                          'from_id': -22822305,
#                          'hash': 'M5iR8sKmK2mIZoQAIw',
#                          'id': 1281889,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1796,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 797, 'user_reposted': 0},
#                          'text': 'ВКонтакте вы всегда можете защитить своё '
#                                  'пространство — настроить приватность '
#                                  'страницы и усилить безопасность профиля. Это '
#                                  'поможет оградить себя и близких от '
#                                  'возможного буллинга в сети или попыток '
#                                  'взлома. Например, когда хотите уйти от '
#                                  'враждебных споров и уберечь личную '
#                                  'информацию от посторонних.\n'
#                                  '\n'
#                                  'В статье три простых совета, которые помогут '
#                                  'вам чувствовать себя ВКонтакте комфортно и '
#                                  'безопасно — сейчас и в будущем.',
#                          'views': {'count': 1594937}},
#                         {'attachments': [{'photo': {'access_key': 'fefc79438c4b5392fa',
#                                                     'album_id': -7,
#                                                     'date': 1647352615,
#                                                     'id': 457329430,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1281405,
#                                                     'sizes': [{'height': 122,
#                                                                'type': 'm',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=130x122&quality=96&sign=2c044396476b10c798f34929f758ae06&c_uniq_tag=7xeVurWNqxQsCuTSHP6qbbzrYzX1h7dZ6_tkO0fqA9Q&type=album',
#                                                                'width': 130},
#                                                               {'height': 122,
#                                                                'type': 'o',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=130x122&quality=96&sign=2c044396476b10c798f34929f758ae06&c_uniq_tag=7xeVurWNqxQsCuTSHP6qbbzrYzX1h7dZ6_tkO0fqA9Q&type=album',
#                                                                'width': 130},
#                                                               {'height': 188,
#                                                                'type': 'p',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=200x188&quality=96&sign=a02ed260d1bef709861fb80d2d1f60a4&c_uniq_tag=FFSPFlO6qw_1cQpxrLz2_kxP5-WpQhUHnM4Hd7IKUI8&type=album',
#                                                                'width': 200},
#                                                               {'height': 300,
#                                                                'type': 'q',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=320x300&quality=96&sign=805050a90ea77f9768b5712ddfe576ce&c_uniq_tag=B8rjx88mWLx9DmqbcXPf95KaHZ9wbePYpJUivRSpeXM&type=album',
#                                                                'width': 320},
#                                                               {'height': 478,
#                                                                'type': 'r',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=510x478&quality=96&sign=949c5607be3927211e27bac5e777fb1a&c_uniq_tag=vMIfwCJz41Ss3evTLFU2-ZgKJiwYcqHTEyKAX8ngZ7o&type=album',
#                                                                'width': 510},
#                                                               {'height': 70,
#                                                                'type': 's',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=75x70&quality=96&sign=f54149ff9f997d474413f0a499f254c6&c_uniq_tag=hj1RjuGI53wDI4IOgAhREK-DgnPNsX3qOgWmfxmSK0o&type=album',
#                                                                'width': 75},
#                                                               {'height': 2157,
#                                                                'type': 'w',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=2300x2157&quality=96&sign=8e3045a0f5f3c753c0b76237ebf39a32&c_uniq_tag=MaSwAoJD8yGETLEdmvdK9PIRhYeXqu50rNzA-TdHRx8&type=album',
#                                                                'width': 2300},
#                                                               {'height': 566,
#                                                                'type': 'x',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=604x566&quality=96&sign=df11dcb078708f88df664d1af4fb71c7&c_uniq_tag=YJBgRVsXFO3LbExSDBoFlK-KBJHjWXqf5hyOqODS4kg&type=album',
#                                                                'width': 604},
#                                                               {'height': 757,
#                                                                'type': 'y',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=807x757&quality=96&sign=d80b969e0eb31b814eec5c93c7a0191e&c_uniq_tag=EFZsePcT1Hi_Hx8_UnSxqnFxAfY4bjyWA6gXNdj1gp4&type=album',
#                                                                'width': 807},
#                                                               {'height': 1200,
#                                                                'type': 'z',
#                                                                'url': 'https://sun6-21.userapi.com/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=1280x1200&quality=96&sign=d44f7f6e996f844ddeb86644a1091097&c_uniq_tag=EUqVjkO4viwW1h2lWuVfAZKHvY40weHkfUxj9YVIYck&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 346,
#                                       'groups_can_post': True},
#                          'date': 1647352647,
#                          'from_id': -22822305,
#                          'hash': '2_xZoDsc1CKr3ZSGXA',
#                          'id': 1281405,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1494,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 410, 'user_reposted': 0},
#                          'text': 'В личном кабинете VK ID появился Центр '
#                                  'управления безопасностью: '
#                                  'id.vk.com/account/#/main. В нём можно '
#                                  'оценить уровень защиты своего аккаунта и '
#                                  'узнать, как её усилить. Система даст '
#                                  'персональные советы: например, если пора '
#                                  'сменить пароль.\n'
#                                  '\n'
#                                  'Это обновление — часть нашей программы VK '
#                                  'Protect. Она объединяет технические решения, '
#                                  'которые обеспечивают безопасность во всех '
#                                  'сервисах VK, и понятное руководство в личном '
#                                  'кабинете. Рекомендации, подсказки и FAQ '
#                                  'помогут выбрать и настроить все инструменты '
#                                  'защиты: надёжный пароль, подтверждение входа '
#                                  'и другие.',
#                          'views': {'count': 1700858}}]}}

# %% [markdown]
# Посмотрим на количество результатов:

# %%
len(response.json()['response']['items'])
## 100
# Out:
# 100

# %% [markdown]
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()['response']['items'][0]
# Out:
# {'id': 1374716,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1672506763,
#  'marked_as_ads': 0,
#  'copy_history': [{'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1672506337,
#       'id': 457240174,
#       'owner_id': 92933,
#       'access_key': '3a7a6d1f7a4cbaf7c5',
#       'post_id': 582,
#       'sizes': [{'height': 130,
#         'type': 'm',
#         'width': 130,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=130x130&quality=96&sign=f78d529693d56329fa208ba57b471e77&c_uniq_tag=ASNzeXj9PQVONyfOi9482YzJHesTpYgrxaDlX0RybLw&type=album'},
#        {'height': 130,
#         'type': 'o',
#         'width': 130,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=130x130&quality=96&sign=f78d529693d56329fa208ba57b471e77&c_uniq_tag=ASNzeXj9PQVONyfOi9482YzJHesTpYgrxaDlX0RybLw&type=album'},
#        {'height': 200,
#         'type': 'p',
#         'width': 200,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=200x200&quality=96&sign=91632907f4d312cc473819be001dc208&c_uniq_tag=CNoGi-sV5Hy0Q-HbtqjPGLU_PMGuKrf50DYxFk3DSVg&type=album'},
#        {'height': 320,
#         'type': 'q',
#         'width': 320,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=320x320&quality=96&sign=e9f9dc6124d8c9c9afc6c592e2e79bc7&c_uniq_tag=DbA9vZNecMcjugpIyIk0TWw88F8NsuzMQkQFRIXKpJs&type=album'},
#        {'height': 510,
#         'type': 'r',
#         'width': 510,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=510x510&quality=96&sign=354c8846b0a1b2e57b26caf17deceeb5&c_uniq_tag=RXI6v_BvNAvFve4YktC6QfTCDDDNrIxCDbuI_-uxtsw&type=album'},
#        {'height': 75,
#         'type': 's',
#         'width': 75,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=75x75&quality=96&sign=9e706c891261f589a9433538baaabda8&c_uniq_tag=x7sT5CwYy84nMwFWIj_qk9O6qiauZiRq_CyiyTTyUIw&type=album'},
#        {'height': 2000,
#         'type': 'w',
#         'width': 2000,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=2000x2000&quality=96&sign=bf760dc9260e2c31c69faabd9768a437&c_uniq_tag=s4uvDu7EV6rLNlastLG-wEv-1vAyKsUHQMtXyRZSjO8&type=album'},
#        {'height': 604,
#         'type': 'x',
#         'width': 604,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=604x604&quality=96&sign=51e3793d2dc188deced8aa0e67714640&c_uniq_tag=UPqFapJLfTMWiiGsDMxCVwzFVE1XCnusqsgfWYdpmIc&type=album'},
#        {'height': 807,
#         'type': 'y',
#         'width': 807,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=807x807&quality=96&sign=7447df0f6bed8830075bf3029d2877d7&c_uniq_tag=U8HZsdSvY9yhAf49ZGr9FBbKqz3JvTLrzwEu4nexFyY&type=album'},
#        {'height': 1280,
#         'type': 'z',
#         'width': 1280,
#         'url': 'https://sun6-22.userapi.com/impg/jaY8va0BpPtOhJ1MiyerQICxqEwZAjF5bhXSAA/E7ouLwQPUNI.jpg?size=1280x1280&quality=96&sign=2461a096b133253d2b177316d776574b&c_uniq_tag=j_QfhccYgHlCr40P3LK3WXLKFw1ScvBJKbaJK5hvZTI&type=album'}],
#       'text': ''}}],
#    'date': 1672506610,
#    'from_id': 92933,
#    'id': 582,
#    'owner_id': 92933,
#    'post_source': {'type': 'vk'},
#    'post_type': 'post',
#    'text': '2022-й без преувеличения можно назвать рекордным для нашей Команды. В течение года мы рассказывали о наших результатах, запусках и ключевых событиях — мы представили свыше 230 продуктовых и технологических обновлений. Улучшения коснулись всех наших продуктов — и это позволило нам добиться невероятных успехов. \n\nЕжемесячная аудитория ВКонтакте впервые превысила 100 миллионов пользователей, мы стали первой соцсетью в России по среднему времени посещения, количеству публикаций и авторов, ежедневные просмотры видео на платформе видеотехнологий VK за 11 месяцев выросли на 49%, до 2,75 млрд, VK Звонки названы лучшим решением для видеоконференций на iOS и Android, VK Мессенджер — самым популярным мессенджером у школьников, число приложений на платформе VK Mini Apps достигло отметки 63 тысячи, а VK Клипы стали лидером среди российских сервисов коротких роликов и установили рекорд в 1 млрд ежедневных просмотров.\n\nО результатах мы традиционно рассказывали на протяжении всего декабря в специальном разделе ВКонтакте: vk.com/2022 — здесь сможете узнать больше про наши продуктовые итоги, благотворительные инициативы и технологические обновления, среди которых — новая рекомендательная система VK Клипов, совместный просмотр медиаконтента во время видеоконференций, уникальные цифровые аватары vmoji, запуск VK NFT и многое другое.\n\nЗа каждым запуском, обновлением и технологическим прорывом стоит большая Команда, которая каждый день работает над созданием простых и удобных инструментов коммуникации. Спасибо Команде ВКонтакте — талантливейшим людям, которые вдохновляют и восхищают. Верю, что в следующем году нас ждёт ещё больше крутых обновлений, технологичных инструментов и новых побед! \n\nМы будем рады создавать и развивать наши сервисы — чтобы помогать вам общаться с друзьями, быть на связи с семьёй, находить единомышленников и новые знакомства, эффективно развивать свой бизнес, учиться и саморазвиваться, отдыхать и веселиться, продуктивно заниматься повседневными вопросами, получать новые впечатления и делиться ими с другими. Пусть в 2023-м всегда будет чем поделиться! \n\nС наступающим Новым годом! Будем ВКонтакте 💙'}],
#  'comments': {'can_post': 1, 'count': 300, 'groups_can_post': True},
#  'attachments': [],
#  'likes': {'can_like': 1, 'count': 1996, 'user_likes': 0, 'can_publish': 1},
#  'post_source': {'platform': 'iphone', 'type': 'api'},
#  'post_type': 'post',
#  'reposts': {'count': 479, 'user_reposted': 0},
#  'text': '',
#  'views': {'count': 375761},
#  'hash': 'gS9QvURcyoUvNo_zHw'}

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.

# %% [markdown]
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'CEO ВКонтакте Марина Краснова ': [115, 751, 268, 1672419951],
#  'А вот и рейтинг главных мемов ': [417, 3966, 1157, 1672210020],
#  'В VK Звонках теперь можно вмес': [145, 1538, 652, 1671629171],
#  'В Петербурге открылся первый м': [300, 1055, 444, 1671796635],
#  'ВКонтакте есть добрая новогодн': [117, 1266, 294, 1672300776],
#  'ВКонтакте много ценителей куль': [141, 1140, 343, 1671712120],
#  'Год выдался насыщенным на техн': [310, 1004, 316, 1672061199],
#  'Предупредим вас о потенциально': [240, 1048, 327, 1672123320],
#  'Уже 8 млн человек общаются с п': [244, 10922, 3016, 1671701804],
#  'Что обсуждали, смотрели и слуш': [175, 1054, 299, 1672328610]}

# %% [markdown]
# Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: всё, что можно делать вручную через браузер, доступно и в API.

# %% [markdown]
# ДОПОЛНИТЕЛЬНО
#
# Если вы размещаете рекламу во ВКонтакте, то можно выгружать всю статистику через ads API https://vk.com/dev/ads.
#
# Полный список методов ВКонтакте можно посмотреть в документации https://vk.com/dev/methods.

# %% [markdown]
# #### <center>ДРУГИЕ API

# %% [markdown]
# Вы познакомились с интерфейсами прикладного программирования — API (на примере API социальной сети ВКонтакте).
#
# API для разработчиков предоставляют и многие другие платформы. Вот список, пожалуй, самых популярных из них:

# %% [markdown]
# * Google Maps API https://developers.google.com/maps/
# * YouTube API https://developers.google.com/youtube/
# * Twitter API https://dev.twitter.com/overview/documentation
# * Facebook API https://developers.facebook.com/docs/

# %% [markdown]
# Информацию о сторонних API можно найти в каталоге Web API https://www.programmableweb.com/category/all/apis. Также можно воспользоваться интернет-поиском, указав в строке поиска, например, «курсы валют API» или «прогноз погоды api», — среди первых результатов выдачи чаще всего с лёгкостью можно найти ссылки на необходимый функционал.

# %% [markdown]
# ### <center>Как настроить регулярную выгрузку данных

# %% [markdown]
# #### <center>СКРИПТЫ

# %% [markdown]
# *✍ Как уже говорилось, скриптом принято называть небольшую компьютерную программу, которая автоматизирует выполнение некоторой задачи. Программы, которые мы создаём на языке Python, также являются скриптами.*

# %% [markdown]
# Скрипт можно использовать разными способами:
#
# * Если вам нужно выполнить код один раз или выполнять его очень редко (от случая к случаю), вы можете запустить скрипт вручную из командной строки.
# * Если вы, например, написали на Python серверную часть веб-сайта и хотите, чтобы ваш код мог в любое время обрабатывать запросы, вы захотите запустить его как фоновый процесс.

# %% [markdown]
# ? А что делать, если вам нужно, чтобы ваш скрипт запускался иногда? Каждую пятницу, 13-го? В день рождения супруга (или супруги)? Или просто каждый час?

# %% [markdown]
# В этом случае вам нужен автоматический запуск скриптов, или, как часто его называют программисты, **запуск по крону** — от английского акронима **Cron** (англ. Command Run ON) — названия системы для автоматического запуска программ и скриптов на сервере в определённое время.

# %% [markdown]
# Автоматический запуск может понадобиться, например:
#
# * если вы хотите с определённой периодичностью скачивать новую информацию с сайтов, например выполнять парсинг новостей для последующего анализа (как мы уже знаем, этот процесс называется web-scraping);
# * если ваш скрипт должен следить за курсом акций и каждую минуту делать запрос по API, чтобы получить новые котировки;
# * если вы написали обучающую платформу и вам нужно каждый час проверять, кто из студентов приступил к занятиям и насколько успешно продвигается их обучение;
# * если у вас есть 500 вендинговых автоматов по продаже солнечных очков и каждые пять минут вы должны опрашивать все автоматы, чтобы узнать, не закончились ли очки.

# %% [markdown]
# Примеров может быть очень много. В каждом, даже небольшом, проекте обычно есть 5-10 скриптов, которые с определённой периодичностью обновляют сертификаты доменов, очищают место на диске, считают статистику, генерируют отчёты и так далее. Давайте научимся настраивать запуск этих скриптов в соответствии с задачами, которые стоят перед вами.

# %% [markdown]
# #### <center>КАК НАСТРОИТЬ АВТОМАТИЧЕСКИЙ ЗАПУСК

# %% [markdown]
# Во всех операционных системах есть встроенные средства запуска программ по расписанию. Однако можно задать расписание запуска необходимых вам функций на языке Python внутри скрипта.
#
# Исполняемый по расписанию код часто называют **задачей** (англ. task). Для планирования задач в Python есть несколько библиотек, среди которых — популярный и простой в использовании модуль schedule (c англ. расписание). Он позволяет запускать код как с определённым интервалом, так и в заданное время.
#
# Модуль schedule не входит в стандартную библиотеку Python, поэтому его необходимо установить:

# %%
# Устанавливаем библиотеку schedule
# !pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.1.0

# %% [markdown]
# Для того чтобы у нас появилась возможность использовать модуль в коде, импортируем его:

# %%
import schedule # Импортируем модуль schedule

# %% [markdown]
# Теперь можно приступать к работе!

# %% [markdown]
# #### <center>ПОСТАНОВКА ЗАДАЧИ

# %% [markdown]
# Рассмотрим вариант автоматического запуска простой функции, которая выводит на экран короткое сообщение:
#
# ```python
# def task():
#     print('Hello! I am a task!')
#     return
# ```

# %% [markdown]
# Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
#
# Для запуска задачи через определённые интервалы времени в модуле schedule используется метод every(), который получает в качестве единственного аргумента число, указывающее, как часто следует запускать код.

# %% [markdown]
# Далее вызывается метод, определяющий единицы измерения промежутков времени, через которые будет выполняться функция. В нашем примере это минуты. Вот как будет выглядеть итоговый код:
#
# ```python
# schedule.every(15).minutes.do(task)
# ```

# %% [markdown]
# Если бы мы хотели запускать задачу, например, каждый час, то могли бы написать:
#
# ```python
# schedule.every(1).hour.do(task)
# ```

# %% [markdown]
# #### <center>ВЫПОЛНЕНИЕ ФУНКЦИИ

# %% [markdown]
# После того как мы создали нашу функцию и определились со временем её запуска, мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Да-да, именно так, ведь скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Давайте напишем этот код.

# %% [markdown]
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля:
#
# ```python
# import time
# while True:
#     schedule.run_pending()
#     time.sleep(1)
# ```

# %% [markdown]
# Всё готово — теперь можно сохранить файл и выполнить код.

# %% [markdown]
# Вот какой код в итоге получился:
#
# ```python
# import schedule
#
# def task():
#     print('Hello! I am a task!')
#     return
#
# schedule.every(15).minutes.do(task)
#
# import time
# while True:
#     schedule.run_pending()
#     time.sleep(1)
# ```

# %% [markdown]
# Этот код будет каждую секунду проверять, не надо ли выполнить какую-то задачу, и раз в 15 минут будет выводить на экран фразу: "Hello! I am a task!" Вывод сообщения будет повторяться до тех пор, пока вы не остановите выполнение скрипта.
